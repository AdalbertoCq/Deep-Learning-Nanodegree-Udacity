# %%
# Prepare gym for agent
import gym
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Getting enviroment
env = gym.make('CartPole-v0')
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
print(env.action_space)
env.reset()
state, reward, done, info = env.step(env.action_space.sample())
print(state)
# Out:
# Discrete(2)
# [ 0.02881814 -0.18446311 -0.04327379  0.30948815]

# %% [markdown]
# Two possible actions [0,1]
# State descrived by [position of cart, velocity of cart, angle of pole, rotation rate of pole].
#
# Neural Network implementation to approximate the Q action value function.

# %% [markdown]
# ## Experience Replay memory implementation.

# %%
from collections import deque
class Memory_exp_replay:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)
    
    def add_timestep(self, env_reaction):
        # St, At, Rt1, St1.
        self.buffer.append(env_reaction)
        
    def sample_random(self, sample_size, debug=False):
        # Replace=False, important so it doesn't repeat a sample on the batch
        indexs = np.random.choice(a=np.arange(len(self.buffer)), size=sample_size, replace=False) 
        if debug:
            print(indexs)
        states = list()
        actions = list()
        rewards = list()
        next_states = list()
        for index in indexs:
            states.append(self.buffer[index][0])
            actions.append(self.buffer[index][1])
            rewards.append(self.buffer[index][2])
            next_states.append(self.buffer[index][3])
        batch = [np.array(states), np.array(actions), np.array(rewards), np.array(next_states)]
        return batch

# %% [markdown]
# Testing out the Memory Buffer.

# %%
# Initliaze memory
def populate_memory(env, exp_replay_memory, batch_size_Q, debug=False):
    if debug: 
        print('Order of enviroment reactions')
    content = 0
    s_t1 = env.reset()
    while content < batch_size_Q:
        s_t = s_t1 
        a_t = env.action_space.sample()
        s_t1, r_t1, done, info = env.step(a_t)
        if done:
            s_t1 = np.zeros(s_t.shape)
            if debug: 
                print(content, s_t)
            exp_replay_memory.add_timestep((s_t, a_t, r_t1, s_t1))
            s_t = env.reset()
        else:
            if debug: 
                print(content, s_t)
            exp_replay_memory.add_timestep((s_t, a_t, r_t1, s_t1))
        content += 1
    return exp_replay_memory

memory_size = 100000
batch_size_Q = 20

# Intantiate memory and populate
exp_replay = Memory_exp_replay(memory_size)
exp_replay = populate_memory(env, exp_replay, batch_size_Q, debug=True)

print('Random sample from Memory Buffer')
states, actions, rewards, next_states = exp_replay.sample_random(2, debug=True)
for state in states:
    print(state)
# Out:
# Order of enviroment reactions
# 0 [-0.0279756  -0.01825218 -0.03759038 -0.01097499]
# 1 [-0.02834064  0.17738814 -0.03780988 -0.31527713]
# 2 [-0.02479288  0.3730277  -0.04411542 -0.61964019]
# 3 [-0.01733233  0.56873714 -0.05650823 -0.92588446]
# 4 [-0.00595758  0.76457483 -0.07502592 -1.2357767 ]
# 5 [ 0.00933391  0.96057648 -0.09974145 -1.55098904]
# 6 [ 0.02854544  0.76678241 -0.13076123 -1.29101807]
# 7 [ 0.04388109  0.96330187 -0.15658159 -1.62161505]
# 8 [ 0.06314713  0.7703323  -0.18901389 -1.38154894]
# 9 [0. 0. 0. 0.]
# 10 [-0.00125512 -0.14961133 -0.00463465  0.32100127]
# 11 [-0.00424735 -0.34466697  0.00178538  0.61221901]
# 12 [-0.01114069 -0.14957002  0.01402976  0.32009895]
# 13 [-0.01413209  0.04534935  0.02043174  0.03187329]
# 14 [-0.0132251  -0.15005956  0.0210692   0.33093197]
# 15 [-0.0162263   0.04475624  0.02768784  0.04496702]
# 16 [-0.01533117 -0.15075157  0.02858718  0.34625552]
# 17 [-0.0183462  -0.34626825  0.03551229  0.6478142 ]
# 18 [-0.02527157 -0.54186649  0.04846858  0.951465  ]
# 19 [-0.0361089  -0.34742917  0.06749788  0.67439571]
# Random sample from Memory Buffer
# [2 5]
# [-0.02479288  0.3730277  -0.04411542 -0.61964019]
# [ 0.00933391  0.96057648 -0.09974145 -1.55098904]

# %% [markdown]
# ### Memory working well.

# %% [markdown]
# ## Q Value Neural Network inference.

# %%
# Defining NN for the action value function approximation.
class NN_Q_approx:
    def __init__(self, learning_rate, hidden_size, state_space, action_space, name):
        self.learning_rate = learning_rate
        self.state_space = state_space
        self.action_space = action_space
        self.name = name
        with tf.variable_scope(self.name):
            self.inputs = tf.placeholder(dtype=tf.float32, shape=[None, self.state_space], name='state_input')
            
            # Placeholder to choose the action value for the action done.
            self.actions = tf.placeholder(dtype=tf.int32, shape=[None], name='action_output')
            actions_oh = tf.one_hot(self.actions, self.action_space)
            
            self.target_Q = tf.placeholder(dtype=tf.float32, shape= [None], name='target_Q')
            
            self.fc1 = tf.contrib.layers.fully_connected(self.inputs, hidden_size)
            self.fc2 = tf.contrib.layers.fully_connected(self.fc1, hidden_size)
            self.output = tf.contrib.layers.fully_connected(self.fc2, self.action_space, activation_fn=None)
            # Until here for action value prediction.
            
            # Q size [m, action_space] -> sum, size [m, 1]
            self.Q = tf.reduce_sum(tf.multiply(self.output, actions_oh), axis=1)
            
            self.loss = tf.reduce_mean(tf.square(self.Q - self.target_Q))
            self.opt = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss)

# %% [markdown]
# Defining parameters for neural network and replay memory, to test out how NN performs to learn Q values.

# %%
# NN parameters.
learning_rate_nn = 0.0001
hidden_size = 128
state_space = len(state)
action_space = env.action_space.n

# Memory parameters.
memory_size = 100000
batch_size_Q = 32

# Training parameters.
max_episodes = 500
max_steps_episode = 300
gamma = 1

# Exploration parameters
max_epsilon = 1.0
min_epsilon = 0.01
decay_rate = 0.05

# %% [markdown]
# Defining Epislon-Greedy Policy.

# %%
def epsilon_greedy(epsilon, q_value):
    probabilities = np.ones(q_value[0].shape)*epsilon/action_space
    probabilities[np.argmax(q_value[0])] = 1 - epsilon + (epsilon/action_space)
    action = np.random.choice(a=np.arange(action_space), size=1, p=probabilities)
    return int(action)

# %% [markdown]
# Code to run training.

# %%
# Intantiate memory and populate
exp_replay = Memory_exp_replay(memory_size)
exp_replay = populate_memory(env, exp_replay, batch_size_Q)

# Initiliaze TensorFlow Graph
tf.reset_default_graph()
Q_NN = NN_Q_approx(learning_rate=learning_rate_nn, hidden_size=hidden_size, state_space=state_space, action_space=action_space, name='Q_action_value')

training_rewards = list()
training_loss = list()
with tf.Session() as sess:
    # Initializa variables 
    sess.run(tf.global_variables_initializer())
    ep_iter = 0
    
    for i in range(1, max_episodes+1):
        # Intiliazing variables for episode.
        s_t1 = env.reset()
        time_step = 0
        episode_reward = 0
        
        while time_step < max_steps_episode:
            # Watch it learn.
            env.render()
            
            s_t = s_t1
            # Controling epsilon.
            ep_iter += 1
            epsilon = min_epsilon + (max_epsilon - min_epsilon)*np.exp(-decay_rate*i) 
        
            # Find Q Values and select action under E-greedy policy.
            q_values = sess.run(Q_NN.output, feed_dict={Q_NN.inputs:np.array(s_t).reshape((1, -1))})
            a_t = epsilon_greedy(epsilon, q_values)

            s_t1, r_t1, done, info = env.step(a_t)
    
            episode_reward += gamma*r_t1
            time_step += 1
            
            if done:
                # Terminating episode
                time_step = max_steps_episode
                s_t1 = np.zeros(state_space)
                # Update memory
                exp_replay.add_timestep((s_t, a_t, r_t1, s_t1))

                # Tracking information
                training_rewards.append((i, episode_reward))
                training_loss.append((i, loss))
                print('Episode: {}'.format(i),
                      'Total reward: {:.4f}'.format(episode_reward),
                      'Training loss: {:.4f}'.format(loss),
                      'Epsilon: {:.4f}'.format(epsilon))
            else:
                # Update memory
                exp_replay.add_timestep((s_t, a_t, r_t1, s_t1))
            
            # Train network.
            states, actions, rewards, next_states = exp_replay.sample_random(batch_size_Q)
            estiamted_Qs = sess.run(Q_NN.output, feed_dict = {Q_NN.inputs:next_states})
            found_initial = (next_states == np.zeros(states[0].shape)).all(axis=1)
            estiamted_Qs[found_initial] = np.zeros(estiamted_Qs[0].shape)
            
            target_Qs = rewards + gamma*np.max(estiamted_Qs, axis=1)
            
            feed_dict = {Q_NN.inputs:states, Q_NN.actions:actions, Q_NN.target_Q: target_Qs}
            loss, _ = sess.run([Q_NN.loss, Q_NN.opt], feed_dict)
# Out:
# Episode: 1 Total reward: 25.0000 Training loss: 1.0919 Epsilon: 0.9517
# Episode: 2 Total reward: 10.0000 Training loss: 1.0827 Epsilon: 0.9058
# Episode: 3 Total reward: 29.0000 Training loss: 1.1005 Epsilon: 0.8621
# Episode: 4 Total reward: 21.0000 Training loss: 1.1744 Epsilon: 0.8205
# Episode: 5 Total reward: 46.0000 Training loss: 1.3014 Epsilon: 0.7810
# Episode: 6 Total reward: 12.0000 Training loss: 1.2677 Epsilon: 0.7434
# Episode: 7 Total reward: 13.0000 Training loss: 1.5333 Epsilon: 0.7076
# Episode: 8 Total reward: 13.0000 Training loss: 1.5284 Epsilon: 0.6736
# Episode: 9 Total reward: 19.0000 Training loss: 1.5493 Epsilon: 0.6413
# Episode: 10 Total reward: 33.0000 Training loss: 1.9086 Epsilon: 0.6105
# Episode: 11 Total reward: 9.0000 Training loss: 2.4398 Epsilon: 0.5812
# Episode: 12 Total reward: 10.0000 Training loss: 2.1286 Epsilon: 0.5533
# Episode: 13 Total reward: 14.0000 Training loss: 2.4618 Epsilon: 0.5268
# Episode: 14 Total reward: 13.0000 Training loss: 3.8425 Epsilon: 0.5016
# Episode: 15 Total reward: 10.0000 Training loss: 4.0726 Epsilon: 0.4776
# Episode: 16 Total reward: 13.0000 Training loss: 4.8767 Epsilon: 0.4548
# Episode: 17 Total reward: 12.0000 Training loss: 3.0258 Epsilon: 0.4331
# Episode: 18 Total reward: 16.0000 Training loss: 3.6944 Epsilon: 0.4125
# Episode: 19 Total reward: 11.0000 Training loss: 10.8903 Epsilon: 0.3929
# Episode: 20 Total reward: 12.0000 Training loss: 3.7037 Epsilon: 0.3742
# Episode: 21 Total reward: 20.0000 Training loss: 13.0174 Epsilon: 0.3564
# Episode: 22 Total reward: 12.0000 Training loss: 18.7458 Epsilon: 0.3395
# Episode: 23 Total reward: 9.0000 Training loss: 4.4315 Epsilon: 0.3235
# Episode: 24 Total reward: 12.0000 Training loss: 10.6515 Epsilon: 0.3082
# Episode: 25 Total reward: 11.0000 Training loss: 15.1713 Epsilon: 0.2936
# Episode: 26 Total reward: 9.0000 Training loss: 8.0189 Epsilon: 0.2798
# Episode: 27 Total reward: 13.0000 Training loss: 14.9631 Epsilon: 0.2666
# Episode: 28 Total reward: 12.0000 Training loss: 12.3728 Epsilon: 0.2541
# Episode: 29 Total reward: 9.0000 Training loss: 21.9719 Epsilon: 0.2422
# Episode: 30 Total reward: 10.0000 Training loss: 29.2630 Epsilon: 0.2309
# Episode: 31 Total reward: 13.0000 Training loss: 31.9976 Epsilon: 0.2201
# Episode: 32 Total reward: 10.0000 Training loss: 25.1932 Epsilon: 0.2099
# Episode: 33 Total reward: 9.0000 Training loss: 35.4527 Epsilon: 0.2001
# Episode: 34 Total reward: 10.0000 Training loss: 32.1946 Epsilon: 0.1909
# Episode: 35 Total reward: 9.0000 Training loss: 24.1713 Epsilon: 0.1820
# Episode: 36 Total reward: 10.0000 Training loss: 35.3337 Epsilon: 0.1736
# Episode: 37 Total reward: 9.0000 Training loss: 29.6206 Epsilon: 0.1657
# Episode: 38 Total reward: 10.0000 Training loss: 12.9252 Epsilon: 0.1581
# Episode: 39 Total reward: 9.0000 Training loss: 34.9547 Epsilon: 0.1509
# Episode: 40 Total reward: 8.0000 Training loss: 17.8481 Epsilon: 0.1440
# Episode: 41 Total reward: 10.0000 Training loss: 14.8875 Epsilon: 0.1374
# Episode: 42 Total reward: 9.0000 Training loss: 25.7662 Epsilon: 0.1312
# Episode: 43 Total reward: 11.0000 Training loss: 24.3371 Epsilon: 0.1253
# Episode: 44 Total reward: 10.0000 Training loss: 15.5244 Epsilon: 0.1197
# Episode: 45 Total reward: 9.0000 Training loss: 12.4920 Epsilon: 0.1143
# Episode: 46 Total reward: 9.0000 Training loss: 23.9491 Epsilon: 0.1093
# Episode: 47 Total reward: 12.0000 Training loss: 14.4249 Epsilon: 0.1044
# Episode: 48 Total reward: 9.0000 Training loss: 39.3101 Epsilon: 0.0998
# Episode: 49 Total reward: 10.0000 Training loss: 25.4246 Epsilon: 0.0954
# Episode: 50 Total reward: 9.0000 Training loss: 26.7002 Epsilon: 0.0913
# Episode: 51 Total reward: 13.0000 Training loss: 5.5562 Epsilon: 0.0873
# Episode: 52 Total reward: 9.0000 Training loss: 33.0593 Epsilon: 0.0835
# Episode: 53 Total reward: 10.0000 Training loss: 24.5849 Epsilon: 0.0799
# Episode: 54 Total reward: 9.0000 Training loss: 29.0388 Epsilon: 0.0765
# Episode: 55 Total reward: 11.0000 Training loss: 37.8456 Epsilon: 0.0733
# Episode: 56 Total reward: 9.0000 Training loss: 14.6544 Epsilon: 0.0702
# Episode: 57 Total reward: 9.0000 Training loss: 24.0591 Epsilon: 0.0673
# Episode: 58 Total reward: 10.0000 Training loss: 20.3345 Epsilon: 0.0645
# Episode: 59 Total reward: 10.0000 Training loss: 26.8943 Epsilon: 0.0618
# Episode: 60 Total reward: 8.0000 Training loss: 20.6255 Epsilon: 0.0593
# Episode: 61 Total reward: 8.0000 Training loss: 14.6342 Epsilon: 0.0569
# Episode: 62 Total reward: 10.0000 Training loss: 8.7572 Epsilon: 0.0546
# Episode: 63 Total reward: 12.0000 Training loss: 8.7641 Epsilon: 0.0524
# Episode: 64 Total reward: 9.0000 Training loss: 29.4477 Epsilon: 0.0504
# Episode: 65 Total reward: 9.0000 Training loss: 11.3082 Epsilon: 0.0484
# Episode: 66 Total reward: 9.0000 Training loss: 25.0786 Epsilon: 0.0465
# Episode: 67 Total reward: 10.0000 Training loss: 25.9738 Epsilon: 0.0447
# Episode: 68 Total reward: 9.0000 Training loss: 12.8567 Epsilon: 0.0430
# Episode: 69 Total reward: 9.0000 Training loss: 14.3501 Epsilon: 0.0414
# Episode: 70 Total reward: 9.0000 Training loss: 2.2264 Epsilon: 0.0399
# Episode: 71 Total reward: 11.0000 Training loss: 1.9132 Epsilon: 0.0384
# Episode: 72 Total reward: 9.0000 Training loss: 10.9530 Epsilon: 0.0371
# Episode: 73 Total reward: 11.0000 Training loss: 6.4017 Epsilon: 0.0357
# Episode: 74 Total reward: 11.0000 Training loss: 9.2996 Epsilon: 0.0345
# Episode: 75 Total reward: 11.0000 Training loss: 9.1580 Epsilon: 0.0333
# Episode: 76 Total reward: 12.0000 Training loss: 16.4785 Epsilon: 0.0321
# Episode: 77 Total reward: 12.0000 Training loss: 12.7894 Epsilon: 0.0311
# Episode: 78 Total reward: 11.0000 Training loss: 7.8553 Epsilon: 0.0300
# Episode: 79 Total reward: 10.0000 Training loss: 4.7785 Epsilon: 0.0291
# Episode: 80 Total reward: 10.0000 Training loss: 4.8547 Epsilon: 0.0281
# Episode: 81 Total reward: 11.0000 Training loss: 11.7392 Epsilon: 0.0272
# Episode: 82 Total reward: 13.0000 Training loss: 4.1691 Epsilon: 0.0264
# Episode: 83 Total reward: 11.0000 Training loss: 9.0262 Epsilon: 0.0256
# Episode: 84 Total reward: 11.0000 Training loss: 9.8224 Epsilon: 0.0248
# Episode: 85 Total reward: 10.0000 Training loss: 14.7194 Epsilon: 0.0241
# Episode: 86 Total reward: 13.0000 Training loss: 9.1404 Epsilon: 0.0234
# Episode: 87 Total reward: 13.0000 Training loss: 3.6198 Epsilon: 0.0228
# Episode: 88 Total reward: 13.0000 Training loss: 6.7737 Epsilon: 0.0222
# Episode: 89 Total reward: 13.0000 Training loss: 1.8420 Epsilon: 0.0216
# Episode: 90 Total reward: 11.0000 Training loss: 6.4467 Epsilon: 0.0210
# Episode: 91 Total reward: 13.0000 Training loss: 7.9880 Epsilon: 0.0205
# Episode: 92 Total reward: 14.0000 Training loss: 23.7144 Epsilon: 0.0200
# Episode: 93 Total reward: 8.0000 Training loss: 9.9879 Epsilon: 0.0195
# Episode: 94 Total reward: 12.0000 Training loss: 8.0126 Epsilon: 0.0190
# Episode: 95 Total reward: 9.0000 Training loss: 7.1354 Epsilon: 0.0186
# Episode: 96 Total reward: 12.0000 Training loss: 9.2214 Epsilon: 0.0181
# Episode: 97 Total reward: 9.0000 Training loss: 7.5859 Epsilon: 0.0178
# Episode: 98 Total reward: 9.0000 Training loss: 28.9001 Epsilon: 0.0174
# Episode: 99 Total reward: 10.0000 Training loss: 4.0159 Epsilon: 0.0170
# Episode: 100 Total reward: 9.0000 Training loss: 23.0889 Epsilon: 0.0167
# Episode: 101 Total reward: 10.0000 Training loss: 27.0692 Epsilon: 0.0163
# Episode: 102 Total reward: 11.0000 Training loss: 5.0934 Epsilon: 0.0160
# Episode: 103 Total reward: 14.0000 Training loss: 6.1230 Epsilon: 0.0157
# Episode: 104 Total reward: 9.0000 Training loss: 28.8852 Epsilon: 0.0155
# Episode: 105 Total reward: 9.0000 Training loss: 5.2266 Epsilon: 0.0152
# Episode: 106 Total reward: 10.0000 Training loss: 6.6460 Epsilon: 0.0149
# Episode: 107 Total reward: 9.0000 Training loss: 11.7278 Epsilon: 0.0147
# Episode: 108 Total reward: 9.0000 Training loss: 9.3469 Epsilon: 0.0145
# Episode: 109 Total reward: 10.0000 Training loss: 4.5601 Epsilon: 0.0143
# Episode: 110 Total reward: 8.0000 Training loss: 1.6873 Epsilon: 0.0140
# Episode: 111 Total reward: 10.0000 Training loss: 25.5237 Epsilon: 0.0138
# Episode: 112 Total reward: 10.0000 Training loss: 21.6923 Epsilon: 0.0137
# Episode: 113 Total reward: 9.0000 Training loss: 2.5470 Epsilon: 0.0135
# Episode: 114 Total reward: 9.0000 Training loss: 9.4632 Epsilon: 0.0133
# Episode: 115 Total reward: 10.0000 Training loss: 46.2645 Epsilon: 0.0132
# Episode: 116 Total reward: 10.0000 Training loss: 27.8998 Epsilon: 0.0130
# Episode: 117 Total reward: 13.0000 Training loss: 4.0082 Epsilon: 0.0129
# Episode: 118 Total reward: 12.0000 Training loss: 3.0673 Epsilon: 0.0127
# Episode: 119 Total reward: 14.0000 Training loss: 5.9933 Epsilon: 0.0126
# Episode: 120 Total reward: 13.0000 Training loss: 28.7278 Epsilon: 0.0125
# Episode: 121 Total reward: 12.0000 Training loss: 28.5518 Epsilon: 0.0123
# Episode: 122 Total reward: 12.0000 Training loss: 4.8754 Epsilon: 0.0122
# Episode: 123 Total reward: 11.0000 Training loss: 23.0896 Epsilon: 0.0121
# Episode: 124 Total reward: 14.0000 Training loss: 6.6480 Epsilon: 0.0120
# Episode: 125 Total reward: 12.0000 Training loss: 19.3275 Epsilon: 0.0119
# Episode: 126 Total reward: 13.0000 Training loss: 20.1645 Epsilon: 0.0118
# Episode: 127 Total reward: 11.0000 Training loss: 22.2255 Epsilon: 0.0117
# Episode: 128 Total reward: 13.0000 Training loss: 22.1439 Epsilon: 0.0116
# Episode: 129 Total reward: 11.0000 Training loss: 17.3518 Epsilon: 0.0116
# Episode: 130 Total reward: 13.0000 Training loss: 22.7186 Epsilon: 0.0115
# Episode: 131 Total reward: 10.0000 Training loss: 9.6174 Epsilon: 0.0114
# Episode: 132 Total reward: 13.0000 Training loss: 4.3473 Epsilon: 0.0113
# Episode: 133 Total reward: 14.0000 Training loss: 34.5645 Epsilon: 0.0113
# Episode: 134 Total reward: 12.0000 Training loss: 18.0335 Epsilon: 0.0112
# Episode: 135 Total reward: 10.0000 Training loss: 3.1374 Epsilon: 0.0112
# Episode: 136 Total reward: 10.0000 Training loss: 34.4488 Epsilon: 0.0111
# Episode: 137 Total reward: 11.0000 Training loss: 6.4173 Epsilon: 0.0110
# Episode: 138 Total reward: 13.0000 Training loss: 19.0924 Epsilon: 0.0110
# Episode: 139 Total reward: 11.0000 Training loss: 39.6988 Epsilon: 0.0109
# Episode: 140 Total reward: 13.0000 Training loss: 33.2295 Epsilon: 0.0109
# Episode: 141 Total reward: 13.0000 Training loss: 14.7475 Epsilon: 0.0109
# Episode: 142 Total reward: 11.0000 Training loss: 7.4899 Epsilon: 0.0108
# Episode: 143 Total reward: 13.0000 Training loss: 14.8959 Epsilon: 0.0108
# Episode: 144 Total reward: 15.0000 Training loss: 6.6632 Epsilon: 0.0107
# Episode: 145 Total reward: 12.0000 Training loss: 34.0392 Epsilon: 0.0107
# Episode: 146 Total reward: 14.0000 Training loss: 17.3222 Epsilon: 0.0107
# Episode: 147 Total reward: 14.0000 Training loss: 5.2196 Epsilon: 0.0106
# Episode: 148 Total reward: 15.0000 Training loss: 3.8815 Epsilon: 0.0106
# Episode: 149 Total reward: 13.0000 Training loss: 6.9630 Epsilon: 0.0106
# Episode: 150 Total reward: 13.0000 Training loss: 12.6940 Epsilon: 0.0105
# Episode: 151 Total reward: 15.0000 Training loss: 0.8504 Epsilon: 0.0105
# Episode: 152 Total reward: 12.0000 Training loss: 12.9238 Epsilon: 0.0105
# Episode: 153 Total reward: 12.0000 Training loss: 5.3398 Epsilon: 0.0105
# Episode: 154 Total reward: 15.0000 Training loss: 6.8476 Epsilon: 0.0104
# Episode: 155 Total reward: 13.0000 Training loss: 5.8043 Epsilon: 0.0104
# Episode: 156 Total reward: 17.0000 Training loss: 13.8864 Epsilon: 0.0104
# Episode: 157 Total reward: 12.0000 Training loss: 5.6029 Epsilon: 0.0104
# Episode: 158 Total reward: 16.0000 Training loss: 6.0388 Epsilon: 0.0104
# Episode: 159 Total reward: 15.0000 Training loss: 2.5727 Epsilon: 0.0103
# Episode: 160 Total reward: 17.0000 Training loss: 5.1532 Epsilon: 0.0103
# Episode: 161 Total reward: 15.0000 Training loss: 5.3595 Epsilon: 0.0103
# Episode: 162 Total reward: 16.0000 Training loss: 4.0404 Epsilon: 0.0103
# Episode: 163 Total reward: 15.0000 Training loss: 17.7391 Epsilon: 0.0103
# Episode: 164 Total reward: 14.0000 Training loss: 2.3215 Epsilon: 0.0103
# Episode: 165 Total reward: 11.0000 Training loss: 5.1576 Epsilon: 0.0103
# Episode: 166 Total reward: 13.0000 Training loss: 4.6580 Epsilon: 0.0102
# Episode: 167 Total reward: 15.0000 Training loss: 3.6694 Epsilon: 0.0102
# Episode: 168 Total reward: 13.0000 Training loss: 3.9924 Epsilon: 0.0102
# Episode: 169 Total reward: 17.0000 Training loss: 3.9558 Epsilon: 0.0102
# Episode: 170 Total reward: 14.0000 Training loss: 6.2650 Epsilon: 0.0102
# Episode: 171 Total reward: 16.0000 Training loss: 8.2297 Epsilon: 0.0102
# Episode: 172 Total reward: 14.0000 Training loss: 6.0510 Epsilon: 0.0102
# Episode: 173 Total reward: 20.0000 Training loss: 3.4486 Epsilon: 0.0102
# Episode: 174 Total reward: 19.0000 Training loss: 3.7366 Epsilon: 0.0102
# Episode: 175 Total reward: 18.0000 Training loss: 14.3000 Epsilon: 0.0102
# Episode: 176 Total reward: 18.0000 Training loss: 4.5269 Epsilon: 0.0101
# Episode: 177 Total reward: 21.0000 Training loss: 3.9591 Epsilon: 0.0101
# Episode: 178 Total reward: 20.0000 Training loss: 5.5511 Epsilon: 0.0101
# Episode: 179 Total reward: 114.0000 Training loss: 5.8442 Epsilon: 0.0101
# Episode: 180 Total reward: 21.0000 Training loss: 10.3120 Epsilon: 0.0101
# Episode: 181 Total reward: 16.0000 Training loss: 7.6809 Epsilon: 0.0101
# Episode: 182 Total reward: 14.0000 Training loss: 12.0584 Epsilon: 0.0101
# Episode: 183 Total reward: 18.0000 Training loss: 13.6198 Epsilon: 0.0101
# Episode: 184 Total reward: 17.0000 Training loss: 7.2399 Epsilon: 0.0101
# Episode: 185 Total reward: 19.0000 Training loss: 7.3946 Epsilon: 0.0101
# Episode: 186 Total reward: 25.0000 Training loss: 7.8031 Epsilon: 0.0101
# Episode: 187 Total reward: 103.0000 Training loss: 12.9295 Epsilon: 0.0101
# Episode: 188 Total reward: 38.0000 Training loss: 5.0853 Epsilon: 0.0101
# Episode: 189 Total reward: 62.0000 Training loss: 13.2873 Epsilon: 0.0101
# Episode: 190 Total reward: 22.0000 Training loss: 7.4699 Epsilon: 0.0101
# Episode: 191 Total reward: 72.0000 Training loss: 6.8539 Epsilon: 0.0101
# Episode: 192 Total reward: 18.0000 Training loss: 6.1002 Epsilon: 0.0101
# Episode: 193 Total reward: 30.0000 Training loss: 4.3221 Epsilon: 0.0101
# Episode: 194 Total reward: 30.0000 Training loss: 14.7381 Epsilon: 0.0101
# Episode: 195 Total reward: 20.0000 Training loss: 19.3680 Epsilon: 0.0101
# Episode: 196 Total reward: 96.0000 Training loss: 4.6489 Epsilon: 0.0101
# Episode: 197 Total reward: 47.0000 Training loss: 11.3809 Epsilon: 0.0101
# Episode: 198 Total reward: 30.0000 Training loss: 4.6612 Epsilon: 0.0100
# Episode: 199 Total reward: 85.0000 Training loss: 1.4898 Epsilon: 0.0100
# Episode: 200 Total reward: 29.0000 Training loss: 41.2896 Epsilon: 0.0100
# Episode: 201 Total reward: 76.0000 Training loss: 3.8746 Epsilon: 0.0100
# Episode: 202 Total reward: 49.0000 Training loss: 60.2730 Epsilon: 0.0100
# Episode: 203 Total reward: 26.0000 Training loss: 6.7688 Epsilon: 0.0100
# Episode: 204 Total reward: 63.0000 Training loss: 10.1318 Epsilon: 0.0100
# Episode: 205 Total reward: 37.0000 Training loss: 37.9716 Epsilon: 0.0100
# Episode: 206 Total reward: 62.0000 Training loss: 30.9456 Epsilon: 0.0100
# Episode: 207 Total reward: 131.0000 Training loss: 1.4018 Epsilon: 0.0100
# Episode: 208 Total reward: 52.0000 Training loss: 5.7999 Epsilon: 0.0100
# Episode: 209 Total reward: 31.0000 Training loss: 10.0886 Epsilon: 0.0100
# Episode: 210 Total reward: 45.0000 Training loss: 17.6223 Epsilon: 0.0100
# Episode: 211 Total reward: 33.0000 Training loss: 33.3834 Epsilon: 0.0100
# Episode: 212 Total reward: 44.0000 Training loss: 11.6466 Epsilon: 0.0100
# Episode: 213 Total reward: 45.0000 Training loss: 7.4446 Epsilon: 0.0100
# Episode: 214 Total reward: 75.0000 Training loss: 113.7646 Epsilon: 0.0100
# Episode: 215 Total reward: 73.0000 Training loss: 28.1635 Epsilon: 0.0100
# Episode: 216 Total reward: 39.0000 Training loss: 58.4109 Epsilon: 0.0100
# Episode: 217 Total reward: 30.0000 Training loss: 1.6290 Epsilon: 0.0100
# Episode: 218 Total reward: 29.0000 Training loss: 9.2943 Epsilon: 0.0100
# Episode: 219 Total reward: 17.0000 Training loss: 22.1301 Epsilon: 0.0100
# Episode: 220 Total reward: 18.0000 Training loss: 3.0045 Epsilon: 0.0100
# Episode: 221 Total reward: 21.0000 Training loss: 11.2958 Epsilon: 0.0100
# Episode: 222 Total reward: 28.0000 Training loss: 10.7388 Epsilon: 0.0100
# Episode: 223 Total reward: 25.0000 Training loss: 95.4591 Epsilon: 0.0100
# Episode: 224 Total reward: 21.0000 Training loss: 4.4623 Epsilon: 0.0100
# Episode: 225 Total reward: 26.0000 Training loss: 16.9957 Epsilon: 0.0100
# Episode: 226 Total reward: 26.0000 Training loss: 56.2176 Epsilon: 0.0100
# Episode: 227 Total reward: 24.0000 Training loss: 8.1912 Epsilon: 0.0100
# Episode: 228 Total reward: 23.0000 Training loss: 17.0466 Epsilon: 0.0100
# Episode: 229 Total reward: 22.0000 Training loss: 26.6730 Epsilon: 0.0100
# Episode: 230 Total reward: 20.0000 Training loss: 14.3492 Epsilon: 0.0100
# Episode: 231 Total reward: 39.0000 Training loss: 10.1749 Epsilon: 0.0100
# Episode: 232 Total reward: 35.0000 Training loss: 80.9463 Epsilon: 0.0100
# Episode: 233 Total reward: 18.0000 Training loss: 57.3142 Epsilon: 0.0100
# Episode: 234 Total reward: 25.0000 Training loss: 13.9428 Epsilon: 0.0100
# Episode: 235 Total reward: 30.0000 Training loss: 19.5709 Epsilon: 0.0100
# Episode: 236 Total reward: 17.0000 Training loss: 199.0447 Epsilon: 0.0100
# Episode: 237 Total reward: 26.0000 Training loss: 138.6833 Epsilon: 0.0100
# Episode: 238 Total reward: 19.0000 Training loss: 2.4487 Epsilon: 0.0100
# Episode: 239 Total reward: 20.0000 Training loss: 9.8979 Epsilon: 0.0100
# Episode: 240 Total reward: 18.0000 Training loss: 99.9350 Epsilon: 0.0100
# Episode: 241 Total reward: 18.0000 Training loss: 61.2884 Epsilon: 0.0100
# Episode: 242 Total reward: 25.0000 Training loss: 70.2710 Epsilon: 0.0100
# Episode: 243 Total reward: 51.0000 Training loss: 3.5331 Epsilon: 0.0100
# Episode: 244 Total reward: 48.0000 Training loss: 4.9119 Epsilon: 0.0100
# Episode: 245 Total reward: 23.0000 Training loss: 99.6703 Epsilon: 0.0100
# Episode: 246 Total reward: 20.0000 Training loss: 15.3781 Epsilon: 0.0100
# Episode: 247 Total reward: 15.0000 Training loss: 2.2293 Epsilon: 0.0100
# Episode: 248 Total reward: 18.0000 Training loss: 8.8425 Epsilon: 0.0100
# Episode: 249 Total reward: 17.0000 Training loss: 2.8119 Epsilon: 0.0100
# Episode: 250 Total reward: 16.0000 Training loss: 144.8424 Epsilon: 0.0100
# Episode: 251 Total reward: 21.0000 Training loss: 11.8688 Epsilon: 0.0100
# Episode: 252 Total reward: 30.0000 Training loss: 1.8395 Epsilon: 0.0100
# Episode: 253 Total reward: 22.0000 Training loss: 3.5537 Epsilon: 0.0100
# Episode: 254 Total reward: 22.0000 Training loss: 25.7513 Epsilon: 0.0100
# Episode: 255 Total reward: 26.0000 Training loss: 14.4902 Epsilon: 0.0100
# Episode: 256 Total reward: 20.0000 Training loss: 88.1385 Epsilon: 0.0100
# Episode: 257 Total reward: 16.0000 Training loss: 4.0630 Epsilon: 0.0100
# Episode: 258 Total reward: 21.0000 Training loss: 17.3446 Epsilon: 0.0100
# Episode: 259 Total reward: 24.0000 Training loss: 17.9455 Epsilon: 0.0100
# Episode: 260 Total reward: 18.0000 Training loss: 2.1796 Epsilon: 0.0100
# Episode: 261 Total reward: 18.0000 Training loss: 134.1762 Epsilon: 0.0100
# Episode: 262 Total reward: 17.0000 Training loss: 13.9415 Epsilon: 0.0100
# Episode: 263 Total reward: 19.0000 Training loss: 17.1811 Epsilon: 0.0100
# Episode: 264 Total reward: 43.0000 Training loss: 57.0926 Epsilon: 0.0100
# Episode: 265 Total reward: 20.0000 Training loss: 35.4871 Epsilon: 0.0100
# Episode: 266 Total reward: 20.0000 Training loss: 65.1348 Epsilon: 0.0100
# Episode: 267 Total reward: 21.0000 Training loss: 3.0562 Epsilon: 0.0100
# Episode: 268 Total reward: 20.0000 Training loss: 33.9272 Epsilon: 0.0100
# Episode: 269 Total reward: 25.0000 Training loss: 31.9301 Epsilon: 0.0100
# Episode: 270 Total reward: 18.0000 Training loss: 141.3645 Epsilon: 0.0100
# Episode: 271 Total reward: 19.0000 Training loss: 172.0854 Epsilon: 0.0100
# Episode: 272 Total reward: 28.0000 Training loss: 34.7943 Epsilon: 0.0100
# Episode: 273 Total reward: 27.0000 Training loss: 32.2719 Epsilon: 0.0100
# Episode: 274 Total reward: 16.0000 Training loss: 84.5353 Epsilon: 0.0100
# Episode: 275 Total reward: 22.0000 Training loss: 23.0618 Epsilon: 0.0100
# Episode: 276 Total reward: 23.0000 Training loss: 13.7449 Epsilon: 0.0100
# Episode: 277 Total reward: 14.0000 Training loss: 3.9411 Epsilon: 0.0100
# Episode: 278 Total reward: 25.0000 Training loss: 86.3314 Epsilon: 0.0100
# Episode: 279 Total reward: 21.0000 Training loss: 27.8564 Epsilon: 0.0100
# Episode: 280 Total reward: 23.0000 Training loss: 19.2923 Epsilon: 0.0100
# Episode: 281 Total reward: 27.0000 Training loss: 162.5196 Epsilon: 0.0100
# Episode: 282 Total reward: 28.0000 Training loss: 60.2637 Epsilon: 0.0100
# Episode: 283 Total reward: 24.0000 Training loss: 48.6192 Epsilon: 0.0100
# Episode: 284 Total reward: 21.0000 Training loss: 78.9787 Epsilon: 0.0100
# Episode: 285 Total reward: 23.0000 Training loss: 169.3418 Epsilon: 0.0100
# Episode: 286 Total reward: 32.0000 Training loss: 74.7097 Epsilon: 0.0100
# Episode: 287 Total reward: 27.0000 Training loss: 54.5461 Epsilon: 0.0100
# Episode: 288 Total reward: 38.0000 Training loss: 64.6734 Epsilon: 0.0100
# Episode: 289 Total reward: 41.0000 Training loss: 26.4566 Epsilon: 0.0100
# Episode: 290 Total reward: 27.0000 Training loss: 5.3925 Epsilon: 0.0100
# Episode: 291 Total reward: 37.0000 Training loss: 107.3299 Epsilon: 0.0100
# Episode: 292 Total reward: 37.0000 Training loss: 2.0715 Epsilon: 0.0100
# Episode: 293 Total reward: 45.0000 Training loss: 2.5230 Epsilon: 0.0100
# Episode: 294 Total reward: 79.0000 Training loss: 2.7653 Epsilon: 0.0100
# Episode: 295 Total reward: 39.0000 Training loss: 49.7507 Epsilon: 0.0100
# Episode: 296 Total reward: 37.0000 Training loss: 4.2390 Epsilon: 0.0100
# Episode: 297 Total reward: 59.0000 Training loss: 73.7597 Epsilon: 0.0100
# Episode: 298 Total reward: 28.0000 Training loss: 103.6589 Epsilon: 0.0100
# Episode: 299 Total reward: 29.0000 Training loss: 100.4175 Epsilon: 0.0100
# Episode: 300 Total reward: 50.0000 Training loss: 25.1866 Epsilon: 0.0100
# Episode: 301 Total reward: 38.0000 Training loss: 70.7492 Epsilon: 0.0100
# Episode: 302 Total reward: 34.0000 Training loss: 104.6946 Epsilon: 0.0100
# Episode: 303 Total reward: 31.0000 Training loss: 13.7532 Epsilon: 0.0100
# Episode: 304 Total reward: 32.0000 Training loss: 125.0146 Epsilon: 0.0100
# Episode: 305 Total reward: 60.0000 Training loss: 28.9053 Epsilon: 0.0100
# Episode: 306 Total reward: 39.0000 Training loss: 28.1313 Epsilon: 0.0100
# Episode: 307 Total reward: 46.0000 Training loss: 110.8048 Epsilon: 0.0100
# Episode: 308 Total reward: 51.0000 Training loss: 26.9563 Epsilon: 0.0100
# Episode: 309 Total reward: 103.0000 Training loss: 38.4849 Epsilon: 0.0100
# Episode: 310 Total reward: 52.0000 Training loss: 3.2233 Epsilon: 0.0100
# Episode: 311 Total reward: 36.0000 Training loss: 84.1407 Epsilon: 0.0100
# Episode: 312 Total reward: 156.0000 Training loss: 12.7464 Epsilon: 0.0100
# Episode: 313 Total reward: 43.0000 Training loss: 102.5690 Epsilon: 0.0100
# Episode: 314 Total reward: 104.0000 Training loss: 58.5285 Epsilon: 0.0100
# Episode: 315 Total reward: 79.0000 Training loss: 10.7947 Epsilon: 0.0100
# Episode: 316 Total reward: 46.0000 Training loss: 41.7812 Epsilon: 0.0100
# Episode: 317 Total reward: 134.0000 Training loss: 7.6392 Epsilon: 0.0100
# Episode: 318 Total reward: 48.0000 Training loss: 3.4476 Epsilon: 0.0100
# Episode: 319 Total reward: 87.0000 Training loss: 48.2168 Epsilon: 0.0100
# Episode: 320 Total reward: 99.0000 Training loss: 3.9173 Epsilon: 0.0100
# Episode: 321 Total reward: 110.0000 Training loss: 4.6971 Epsilon: 0.0100
# Episode: 322 Total reward: 60.0000 Training loss: 87.3725 Epsilon: 0.0100
# Episode: 323 Total reward: 44.0000 Training loss: 160.8392 Epsilon: 0.0100
# Episode: 324 Total reward: 39.0000 Training loss: 5.0863 Epsilon: 0.0100
# Episode: 325 Total reward: 70.0000 Training loss: 100.1133 Epsilon: 0.0100
# Episode: 326 Total reward: 47.0000 Training loss: 3.9436 Epsilon: 0.0100
# Episode: 327 Total reward: 41.0000 Training loss: 142.5597 Epsilon: 0.0100
# Episode: 328 Total reward: 67.0000 Training loss: 3.3635 Epsilon: 0.0100
# Episode: 329 Total reward: 82.0000 Training loss: 20.8782 Epsilon: 0.0100
# Episode: 330 Total reward: 198.0000 Training loss: 3.5677 Epsilon: 0.0100
# Episode: 331 Total reward: 64.0000 Training loss: 106.6658 Epsilon: 0.0100
# Episode: 332 Total reward: 47.0000 Training loss: 82.4649 Epsilon: 0.0100
# Episode: 333 Total reward: 56.0000 Training loss: 101.2088 Epsilon: 0.0100
# Episode: 334 Total reward: 87.0000 Training loss: 17.7679 Epsilon: 0.0100
# Episode: 335 Total reward: 80.0000 Training loss: 50.3597 Epsilon: 0.0100
# Episode: 336 Total reward: 49.0000 Training loss: 116.3177 Epsilon: 0.0100
# Episode: 337 Total reward: 39.0000 Training loss: 3.2136 Epsilon: 0.0100
# Episode: 338 Total reward: 76.0000 Training loss: 3.3874 Epsilon: 0.0100
# Episode: 339 Total reward: 119.0000 Training loss: 3.9881 Epsilon: 0.0100
# Episode: 340 Total reward: 107.0000 Training loss: 5.8048 Epsilon: 0.0100
# Episode: 341 Total reward: 88.0000 Training loss: 44.2474 Epsilon: 0.0100
# Episode: 342 Total reward: 44.0000 Training loss: 258.8644 Epsilon: 0.0100
# Episode: 343 Total reward: 53.0000 Training loss: 42.4178 Epsilon: 0.0100
# Episode: 344 Total reward: 131.0000 Training loss: 190.6580 Epsilon: 0.0100
# Episode: 345 Total reward: 75.0000 Training loss: 118.6320 Epsilon: 0.0100
# Episode: 346 Total reward: 54.0000 Training loss: 5.3476 Epsilon: 0.0100
# Episode: 347 Total reward: 121.0000 Training loss: 79.8178 Epsilon: 0.0100
# Episode: 348 Total reward: 35.0000 Training loss: 7.3298 Epsilon: 0.0100
# Episode: 349 Total reward: 67.0000 Training loss: 3.8741 Epsilon: 0.0100
# Episode: 350 Total reward: 129.0000 Training loss: 343.6493 Epsilon: 0.0100
# Episode: 351 Total reward: 96.0000 Training loss: 379.5128 Epsilon: 0.0100
# Episode: 352 Total reward: 95.0000 Training loss: 418.4968 Epsilon: 0.0100
# Episode: 353 Total reward: 200.0000 Training loss: 4.8805 Epsilon: 0.0100
# Episode: 354 Total reward: 200.0000 Training loss: 121.3969 Epsilon: 0.0100
# Episode: 355 Total reward: 200.0000 Training loss: 2.7758 Epsilon: 0.0100
# Episode: 356 Total reward: 162.0000 Training loss: 6.1929 Epsilon: 0.0100
# Episode: 357 Total reward: 82.0000 Training loss: 4.5193 Epsilon: 0.0100
# Episode: 358 Total reward: 156.0000 Training loss: 3.2744 Epsilon: 0.0100
# Episode: 359 Total reward: 200.0000 Training loss: 78.9482 Epsilon: 0.0100
# Episode: 360 Total reward: 200.0000 Training loss: 4.5654 Epsilon: 0.0100
# Episode: 361 Total reward: 162.0000 Training loss: 4.3974 Epsilon: 0.0100
# Episode: 362 Total reward: 96.0000 Training loss: 43.0495 Epsilon: 0.0100
# Episode: 363 Total reward: 94.0000 Training loss: 49.8726 Epsilon: 0.0100
# Episode: 364 Total reward: 200.0000 Training loss: 156.8635 Epsilon: 0.0100
# Episode: 365 Total reward: 78.0000 Training loss: 2.5078 Epsilon: 0.0100
# Episode: 366 Total reward: 169.0000 Training loss: 68.0369 Epsilon: 0.0100
# Episode: 367 Total reward: 102.0000 Training loss: 92.7692 Epsilon: 0.0100
# Episode: 368 Total reward: 107.0000 Training loss: 81.9182 Epsilon: 0.0100
# Episode: 369 Total reward: 187.0000 Training loss: 6.3017 Epsilon: 0.0100
# Episode: 370 Total reward: 200.0000 Training loss: 61.0380 Epsilon: 0.0100
# Episode: 371 Total reward: 85.0000 Training loss: 51.3090 Epsilon: 0.0100
# Episode: 372 Total reward: 175.0000 Training loss: 124.7253 Epsilon: 0.0100
# Episode: 373 Total reward: 107.0000 Training loss: 49.2271 Epsilon: 0.0100
# Episode: 374 Total reward: 200.0000 Training loss: 10.7053 Epsilon: 0.0100
# Episode: 375 Total reward: 100.0000 Training loss: 86.6235 Epsilon: 0.0100
# Episode: 376 Total reward: 108.0000 Training loss: 174.6133 Epsilon: 0.0100
# Episode: 377 Total reward: 130.0000 Training loss: 93.2923 Epsilon: 0.0100
# Episode: 378 Total reward: 184.0000 Training loss: 49.8973 Epsilon: 0.0100
# Episode: 379 Total reward: 129.0000 Training loss: 46.1694 Epsilon: 0.0100
# Episode: 380 Total reward: 134.0000 Training loss: 7.7531 Epsilon: 0.0100
# Episode: 381 Total reward: 200.0000 Training loss: 9.5736 Epsilon: 0.0100
# Episode: 382 Total reward: 113.0000 Training loss: 78.2268 Epsilon: 0.0100
# Episode: 383 Total reward: 200.0000 Training loss: 5.1115 Epsilon: 0.0100
# Episode: 384 Total reward: 200.0000 Training loss: 48.1218 Epsilon: 0.0100
# Episode: 385 Total reward: 200.0000 Training loss: 81.1916 Epsilon: 0.0100
# Episode: 386 Total reward: 200.0000 Training loss: 227.0805 Epsilon: 0.0100
# Episode: 387 Total reward: 181.0000 Training loss: 4.9983 Epsilon: 0.0100
# Episode: 388 Total reward: 160.0000 Training loss: 69.9438 Epsilon: 0.0100
# Episode: 389 Total reward: 200.0000 Training loss: 244.6982 Epsilon: 0.0100
# Episode: 390 Total reward: 200.0000 Training loss: 4.6247 Epsilon: 0.0100
# Episode: 391 Total reward: 200.0000 Training loss: 6.6603 Epsilon: 0.0100
# Episode: 392 Total reward: 200.0000 Training loss: 91.7258 Epsilon: 0.0100
# Episode: 393 Total reward: 157.0000 Training loss: 266.0341 Epsilon: 0.0100
# Episode: 394 Total reward: 192.0000 Training loss: 58.8449 Epsilon: 0.0100
# Episode: 395 Total reward: 200.0000 Training loss: 160.7298 Epsilon: 0.0100
# Episode: 396 Total reward: 200.0000 Training loss: 7.4784 Epsilon: 0.0100
# Episode: 397 Total reward: 200.0000 Training loss: 166.4994 Epsilon: 0.0100
# Episode: 398 Total reward: 183.0000 Training loss: 6.2861 Epsilon: 0.0100
# Episode: 399 Total reward: 200.0000 Training loss: 112.2354 Epsilon: 0.0100
# Episode: 400 Total reward: 200.0000 Training loss: 102.7492 Epsilon: 0.0100
# Episode: 401 Total reward: 200.0000 Training loss: 346.2798 Epsilon: 0.0100
# Episode: 402 Total reward: 200.0000 Training loss: 140.8322 Epsilon: 0.0100
# Episode: 403 Total reward: 200.0000 Training loss: 640.6571 Epsilon: 0.0100
# Episode: 404 Total reward: 167.0000 Training loss: 113.6086 Epsilon: 0.0100
# Episode: 405 Total reward: 200.0000 Training loss: 396.0955 Epsilon: 0.0100
# Episode: 406 Total reward: 200.0000 Training loss: 8.6701 Epsilon: 0.0100
# Episode: 407 Total reward: 200.0000 Training loss: 164.4452 Epsilon: 0.0100
# Episode: 408 Total reward: 200.0000 Training loss: 336.9471 Epsilon: 0.0100
# Episode: 409 Total reward: 200.0000 Training loss: 180.9335 Epsilon: 0.0100
# Episode: 410 Total reward: 200.0000 Training loss: 11.9864 Epsilon: 0.0100
# Episode: 411 Total reward: 200.0000 Training loss: 29.7137 Epsilon: 0.0100
# Episode: 412 Total reward: 200.0000 Training loss: 507.1802 Epsilon: 0.0100
# Episode: 413 Total reward: 200.0000 Training loss: 238.6363 Epsilon: 0.0100
# Episode: 414 Total reward: 200.0000 Training loss: 25.7099 Epsilon: 0.0100
# Episode: 415 Total reward: 200.0000 Training loss: 12.3413 Epsilon: 0.0100
# Episode: 416 Total reward: 200.0000 Training loss: 198.1153 Epsilon: 0.0100
# Episode: 417 Total reward: 200.0000 Training loss: 218.2131 Epsilon: 0.0100
# Episode: 418 Total reward: 200.0000 Training loss: 10.7275 Epsilon: 0.0100
# Episode: 419 Total reward: 200.0000 Training loss: 292.9193 Epsilon: 0.0100
# Episode: 420 Total reward: 200.0000 Training loss: 5.7222 Epsilon: 0.0100
# Episode: 421 Total reward: 200.0000 Training loss: 384.2773 Epsilon: 0.0100
# Episode: 422 Total reward: 200.0000 Training loss: 733.3589 Epsilon: 0.0100
# Episode: 423 Total reward: 200.0000 Training loss: 10.8250 Epsilon: 0.0100
# Episode: 424 Total reward: 200.0000 Training loss: 9.8870 Epsilon: 0.0100
# Episode: 425 Total reward: 200.0000 Training loss: 10.8314 Epsilon: 0.0100
# Episode: 426 Total reward: 200.0000 Training loss: 9.7588 Epsilon: 0.0100
# Episode: 427 Total reward: 200.0000 Training loss: 224.6030 Epsilon: 0.0100
# Episode: 428 Total reward: 200.0000 Training loss: 12.0906 Epsilon: 0.0100
# Episode: 429 Total reward: 200.0000 Training loss: 452.2167 Epsilon: 0.0100
# Episode: 430 Total reward: 200.0000 Training loss: 5.7896 Epsilon: 0.0100
# Episode: 431 Total reward: 200.0000 Training loss: 280.1127 Epsilon: 0.0100
# Episode: 432 Total reward: 200.0000 Training loss: 5.9274 Epsilon: 0.0100
# Episode: 433 Total reward: 200.0000 Training loss: 12.5972 Epsilon: 0.0100
# Episode: 434 Total reward: 200.0000 Training loss: 5.9081 Epsilon: 0.0100
# Episode: 435 Total reward: 200.0000 Training loss: 11.9868 Epsilon: 0.0100
# Episode: 436 Total reward: 200.0000 Training loss: 11.7431 Epsilon: 0.0100
# Episode: 437 Total reward: 200.0000 Training loss: 14.6716 Epsilon: 0.0100
# Episode: 438 Total reward: 200.0000 Training loss: 16.5940 Epsilon: 0.0100
# Episode: 439 Total reward: 200.0000 Training loss: 10.3553 Epsilon: 0.0100
# Episode: 440 Total reward: 200.0000 Training loss: 467.4891 Epsilon: 0.0100
# Episode: 441 Total reward: 200.0000 Training loss: 11.6507 Epsilon: 0.0100
# Episode: 442 Total reward: 200.0000 Training loss: 420.5689 Epsilon: 0.0100
# Episode: 443 Total reward: 200.0000 Training loss: 8.9130 Epsilon: 0.0100
# Episode: 444 Total reward: 200.0000 Training loss: 338.7142 Epsilon: 0.0100
# Episode: 445 Total reward: 200.0000 Training loss: 37.7632 Epsilon: 0.0100
# Episode: 446 Total reward: 200.0000 Training loss: 9.5171 Epsilon: 0.0100
# Episode: 447 Total reward: 200.0000 Training loss: 13.9245 Epsilon: 0.0100
# Episode: 448 Total reward: 200.0000 Training loss: 168.7801 Epsilon: 0.0100
# Episode: 449 Total reward: 200.0000 Training loss: 706.7059 Epsilon: 0.0100
# Episode: 450 Total reward: 200.0000 Training loss: 13.9137 Epsilon: 0.0100
# Episode: 451 Total reward: 200.0000 Training loss: 17.9119 Epsilon: 0.0100
# Episode: 452 Total reward: 200.0000 Training loss: 20.8230 Epsilon: 0.0100
# Episode: 453 Total reward: 200.0000 Training loss: 2056.3237 Epsilon: 0.0100
# Episode: 454 Total reward: 200.0000 Training loss: 11.9728 Epsilon: 0.0100
# Episode: 455 Total reward: 200.0000 Training loss: 25.1221 Epsilon: 0.0100
# Episode: 456 Total reward: 200.0000 Training loss: 167.2571 Epsilon: 0.0100
# Episode: 457 Total reward: 200.0000 Training loss: 16.8642 Epsilon: 0.0100
# Episode: 458 Total reward: 200.0000 Training loss: 89.8761 Epsilon: 0.0100
# Episode: 459 Total reward: 200.0000 Training loss: 540.6304 Epsilon: 0.0100
# Episode: 460 Total reward: 200.0000 Training loss: 11.3419 Epsilon: 0.0100
# Episode: 461 Total reward: 200.0000 Training loss: 23.5575 Epsilon: 0.0100
# Episode: 462 Total reward: 200.0000 Training loss: 197.0106 Epsilon: 0.0100
# Episode: 463 Total reward: 200.0000 Training loss: 12.8977 Epsilon: 0.0100
# Episode: 464 Total reward: 200.0000 Training loss: 682.6773 Epsilon: 0.0100
# Episode: 465 Total reward: 200.0000 Training loss: 23.2775 Epsilon: 0.0100
# Episode: 466 Total reward: 200.0000 Training loss: 8.1108 Epsilon: 0.0100
# Episode: 467 Total reward: 200.0000 Training loss: 7.1590 Epsilon: 0.0100
# Episode: 468 Total reward: 200.0000 Training loss: 253.6459 Epsilon: 0.0100
# Episode: 469 Total reward: 200.0000 Training loss: 10.6807 Epsilon: 0.0100
# Episode: 470 Total reward: 200.0000 Training loss: 111.2376 Epsilon: 0.0100
# Episode: 471 Total reward: 200.0000 Training loss: 17.3382 Epsilon: 0.0100
# Episode: 472 Total reward: 200.0000 Training loss: 13.1004 Epsilon: 0.0100
# Episode: 473 Total reward: 200.0000 Training loss: 18.9038 Epsilon: 0.0100
# Episode: 474 Total reward: 200.0000 Training loss: 7.5686 Epsilon: 0.0100
# Episode: 475 Total reward: 200.0000 Training loss: 23.5719 Epsilon: 0.0100
# Episode: 476 Total reward: 200.0000 Training loss: 43.9313 Epsilon: 0.0100
# Episode: 477 Total reward: 200.0000 Training loss: 18.7973 Epsilon: 0.0100
# Episode: 478 Total reward: 200.0000 Training loss: 14.6747 Epsilon: 0.0100
# Episode: 479 Total reward: 200.0000 Training loss: 2917.8279 Epsilon: 0.0100
# Episode: 480 Total reward: 200.0000 Training loss: 9.8255 Epsilon: 0.0100
# Episode: 481 Total reward: 200.0000 Training loss: 448.6644 Epsilon: 0.0100
# Episode: 482 Total reward: 200.0000 Training loss: 9.4864 Epsilon: 0.0100
# Episode: 483 Total reward: 200.0000 Training loss: 18.8428 Epsilon: 0.0100
# Episode: 484 Total reward: 200.0000 Training loss: 87.6545 Epsilon: 0.0100
# Episode: 485 Total reward: 200.0000 Training loss: 19.3641 Epsilon: 0.0100
# Episode: 486 Total reward: 200.0000 Training loss: 17.8881 Epsilon: 0.0100
# Episode: 487 Total reward: 200.0000 Training loss: 30.7425 Epsilon: 0.0100
# Episode: 488 Total reward: 200.0000 Training loss: 162.5092 Epsilon: 0.0100
# Episode: 489 Total reward: 200.0000 Training loss: 2407.0952 Epsilon: 0.0100
# Episode: 490 Total reward: 200.0000 Training loss: 36.6618 Epsilon: 0.0100
# Episode: 491 Total reward: 200.0000 Training loss: 3.9918 Epsilon: 0.0100
# Episode: 492 Total reward: 200.0000 Training loss: 6.6844 Epsilon: 0.0100
# Episode: 493 Total reward: 200.0000 Training loss: 14.0988 Epsilon: 0.0100
# Episode: 494 Total reward: 200.0000 Training loss: 38.3833 Epsilon: 0.0100
# Episode: 495 Total reward: 200.0000 Training loss: 163.7364 Epsilon: 0.0100
# Episode: 496 Total reward: 200.0000 Training loss: 17.9743 Epsilon: 0.0100
# Episode: 497 Total reward: 200.0000 Training loss: 21.3140 Epsilon: 0.0100
# Episode: 498 Total reward: 200.0000 Training loss: 8.4850 Epsilon: 0.0100
# Episode: 499 Total reward: 200.0000 Training loss: 11.7017 Epsilon: 0.0100
# Episode: 500 Total reward: 200.0000 Training loss: 5.4174 Epsilon: 0.0100

# %%
def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / N 

eps, rews = np.array(training_rewards).T
smoothed_rews = running_mean(rews, 10)
plt.plot(eps[-len(smoothed_rews):], smoothed_rews)
plt.plot(eps, rews, color='blue', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.show()

# %%
eps, loss = np.array(training_loss).T
plt.plot(loss, color='blue')
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.show()
