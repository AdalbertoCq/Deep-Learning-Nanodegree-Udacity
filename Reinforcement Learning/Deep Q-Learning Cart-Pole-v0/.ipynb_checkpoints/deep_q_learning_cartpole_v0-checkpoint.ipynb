# %%
# Prepare gym for agent
import gym
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Getting enviroment
env = gym.make('CartPole-v0')
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
print(env.action_space)
env.reset()
state, reward, done, info = env.step(env.action_space.sample())
print(state)
# Out:
# Discrete(2)
# [ 0.02151765 -0.14487298 -0.03423022  0.25963942]

# %% [markdown]
# Two possible actions [0,1]
# State descrived by [position of cart, velocity of cart, angle of pole, rotation rate of pole].
#
# Neural Network implementation to approximate the Q action value function.

# %% [markdown]
# ## Experience Replay memory implementation.

# %%
from collections import deque
class Memory_exp_replay:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)
    
    def add_timestep(self, env_reaction):
        # St, At, Rt1, St1.
        self.buffer.append(env_reaction)
        
    def sample_random(self, sample_size, debug=False):
        # Replace=False, important so it doesn't repeat a sample on the batch
        indexs = np.random.choice(a=np.arange(len(self.buffer)), size=sample_size, replace=False) 
        if debug:
            print(indexs)
        states = list()
        actions = list()
        rewards = list()
        next_states = list()
        for index in indexs:
            states.append(self.buffer[index][0])
            actions.append(self.buffer[index][1])
            rewards.append(self.buffer[index][2])
            next_states.append(self.buffer[index][3])
        batch = [np.array(states), np.array(actions), np.array(rewards), np.array(next_states)]
        return batch

# %% [markdown]
# Testing out the Memory Buffer.

# %%
# Initliaze memory
def populate_memory(env, exp_replay_memory, batch_size_Q, debug=False):
    if debug: 
        print('Order of enviroment reactions')
    content = 0
    s_t1 = env.reset()
    while content < batch_size_Q:
        s_t = s_t1 
        a_t = env.action_space.sample()
        s_t1, r_t1, done, info = env.step(a_t)
        if done:
            s_t1 = np.zeros(s_t.shape)
            if debug: 
                print(content, s_t)
            exp_replay_memory.add_timestep((s_t, a_t, r_t1, s_t1))
            s_t = env.reset()
        else:
            if debug: 
                print(content, s_t)
            exp_replay_memory.add_timestep((s_t, a_t, r_t1, s_t1))
        content += 1
    return exp_replay_memory

memory_size = 100000
batch_size_Q = 20

# Intantiate memory and populate
exp_replay = Memory_exp_replay(memory_size)
exp_replay = populate_memory(env, exp_replay, batch_size_Q, debug=True)

print('Random sample from Memory Buffer')
states, actions, rewards, next_states = exp_replay.sample_random(2, debug=True)
for state in states:
    print(state)
# Out:
# Order of enviroment reactions
# 0 [ 0.01797903 -0.02290754  0.01082873 -0.02835414]
# 1 [ 0.01752088  0.17205746  0.01026165 -0.31760091]
# 2 [ 0.02096203  0.36703176  0.00390963 -0.6070301 ]
# 3 [ 0.02830266  0.17185536 -0.00823097 -0.31311831]
# 4 [ 0.03173977  0.3670936  -0.01449334 -0.60838562]
# 5 [ 0.03908164  0.56241514 -0.02666105 -0.90559805]
# 6 [ 0.05032995  0.75788778 -0.04477301 -1.20654022]
# 7 [ 0.0654877   0.95355873 -0.06890381 -1.51291139]
# 8 [ 0.08455888  1.14944405 -0.09916204 -1.82628383]
# 9 [ 0.10754776  1.34551608 -0.13568772 -2.14805294]
# 10 [ 0.13445808  1.5416886  -0.17864878 -2.47937694]
# 11 [0. 0. 0. 0.]
# 12 [ 0.04209569 -0.2008158  -0.01642993  0.24836973]
# 13 [ 0.03807938 -0.00546311 -0.01146254 -0.04944994]
# 14 [ 0.03797011 -0.20041884 -0.01245154  0.23959453]
# 15 [ 0.03396174 -0.39536072 -0.00765965  0.52832403]
# 16 [ 0.02605452 -0.59037407  0.00290684  0.81858357]
# 17 [ 0.01424704 -0.78553569  0.01927851  1.11217937]
# 18 [-0.00146367 -0.98090548  0.04152209  1.41084712]
# 19 [-0.02108178 -0.78632225  0.06973904  1.13142785]
# Random sample from Memory Buffer
# [11 12]
# [0. 0. 0. 0.]
# [ 0.04209569 -0.2008158  -0.01642993  0.24836973]

# %% [markdown]
# ### Memory working well.

# %% [markdown]
# ## Q Value Neural Network inference.

# %%
# Defining NN for the action value function approximation.
class NN_Q_approx:
    def __init__(self, learning_rate, hidden_size, state_space, action_space, name):
        self.learning_rate = learning_rate
        self.state_space = state_space
        self.action_space = action_space
        self.name = name
        with tf.variable_scope(self.name):
            self.inputs = tf.placeholder(dtype=tf.float32, shape=[None, self.state_space], name='state_input')
            
            # Placeholder to choose the action value for the action done.
            self.actions = tf.placeholder(dtype=tf.int32, shape=[None], name='action_output')
            actions_oh = tf.one_hot(self.actions, self.action_space)
            
            self.target_Q = tf.placeholder(dtype=tf.float32, shape= [None], name='target_Q')
            
            self.fc1 = tf.contrib.layers.fully_connected(self.inputs, hidden_size, scope='fc1')
            self.fc2 = tf.contrib.layers.fully_connected(self.fc1, hidden_size, scope='fc2')
            self.output = tf.contrib.layers.fully_connected(self.fc2, self.action_space, activation_fn=None, scope='output')
            # Until here for action value prediction.
            
            # Q size [m, action_space] -> sum, size [m, 1]
            self.Q = tf.reduce_sum(tf.multiply(self.output, actions_oh), axis=1)
            
            self.loss = tf.reduce_mean(tf.square(self.Q - self.target_Q))
            self.opt = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss)

# %% [markdown]
# Defining parameters for neural network and replay memory, to test out how NN performs to learn Q values.

# %%
# NN parameters.
learning_rate_nn = 0.0001
hidden_size = 128
state_space = len(state)
action_space = env.action_space.n

# Memory parameters.
memory_size = 100000
batch_size_Q = 32

# Training parameters.
max_episodes = 1500
max_steps_episode = 300
gamma = 1

# Exploration parameters
max_epsilon = 1.0
min_epsilon = 0.01
decay_rate = 0.05

# Update Target NN weights every X steps.
update_nn_target = 10

# %% [markdown]
# Defining Epislon-Greedy Policy and Weigth update for the Target NN.

# %%
def epsilon_greedy(epsilon, q_value):
    probabilities = np.ones(q_value[0].shape)*epsilon/action_space
    probabilities[np.argmax(q_value[0])] = 1 - epsilon + (epsilon/action_space)
    action = np.random.choice(a=np.arange(action_space), size=1, p=probabilities)
    return int(action)


# If I don't assign the value and variable relationship before each iteration, it is incredibly slow.
# Assigning the relationship of the graph and just updating the value is much faster.
def relate_variables_NN(Q_NN_target, Q_NN_grad):
    assigns = list()
    Q_NN_grad_variables =[v for v in tf.trainable_variables() if Q_NN_grad.name in v.name]
    Q_NN_target_variables =[v for v in tf.trainable_variables() if Q_NN_target.name in v.name]
#     Q_NN_grad_values = sess.run(Q_NN_grad_variables)
    for ind_g, var in enumerate(Q_NN_grad_variables):
        for var_target in Q_NN_target_variables:
            if var_target.name.replace(Q_NN_target.name,Q_NN_grad.name)==var.name:
#                 assigns.append(tf.assign(var_target, Q_NN_grad_values[ind_g]))
                assigns.append(tf.assign(var_target, var.value()))
                break

    return assigns

def update_values_sess(sess, assigns):
    for assign_oper in assigns:
        sess.run(assign_oper)

# %% [markdown]
# Code to run training.

# %%
def train_agent():
    # Intantiate memory and populate
    exp_replay = Memory_exp_replay(memory_size)
    exp_replay = populate_memory(env, exp_replay, batch_size_Q)

    # Initiliaze TensorFlow Graph
    tf.reset_default_graph()
    Q_NN_target = NN_Q_approx(learning_rate=learning_rate_nn, hidden_size=hidden_size, state_space=state_space, action_space=action_space, name='Q_action_target')
    Q_NN_grad = NN_Q_approx(learning_rate=learning_rate_nn, hidden_size=hidden_size, state_space=state_space, action_space=action_space, name='Q_action_grad')
    assigns = relate_variables_NN(Q_NN_target, Q_NN_grad)

    training_rewards = list()
    training_loss = list()
    with tf.Session() as sess:
        # Initializa variables 
        sess.run(tf.global_variables_initializer())
        ep_iter = 0

        for i in range(1, max_episodes+1):
            # Intiliazing variables for episode.
            s_t1 = env.reset()
            time_step = 0
            episode_reward = 0

            while time_step < max_steps_episode:
                # Watch it learn.
        #             env.render()

                s_t = s_t1
                # Controling epsilon.
                ep_iter += 1
                epsilon = min_epsilon + (max_epsilon - min_epsilon)*np.exp(-decay_rate*i) 

                # Find Q Values and select action under E-greedy policy.
                q_values = sess.run(Q_NN_grad.output, feed_dict={Q_NN_grad.inputs:np.array(s_t).reshape((1, -1))})
                a_t = epsilon_greedy(epsilon, q_values)

                s_t1, r_t1, done, info = env.step(a_t)

                episode_reward += gamma*r_t1
                time_step += 1

                if done:
                    # Terminating episode
                    time_step = max_steps_episode
                    s_t1 = np.zeros(state_space)
                    # Update memory
                    exp_replay.add_timestep((s_t, a_t, r_t1, s_t1))

                    # Tracking information
                    training_rewards.append((i, episode_reward))
                    training_loss.append((i, loss))
                    print('Episode: {}'.format(i),


                          'Total reward: {:.4f}'.format(episode_reward),
                          'Training loss: {:.4f}'.format(loss),
                          'Epsilon: {:.4f}'.format(epsilon))
                else:
                    # Update memory
                    exp_replay.add_timestep((s_t, a_t, r_t1, s_t1))

                # Train network.
                states, actions, rewards, next_states = exp_replay.sample_random(batch_size_Q)
                estiamted_Qs = sess.run(Q_NN_target.output, feed_dict = {Q_NN_target.inputs:next_states})
                found_initial = (next_states == np.zeros(states[0].shape)).all(axis=1)
                estiamted_Qs[found_initial] = np.zeros(estiamted_Qs[0].shape)

                target_Qs = rewards + gamma*np.max(estiamted_Qs, axis=1)

                feed_dict = {Q_NN_grad.inputs:states, Q_NN_grad.actions:actions, Q_NN_grad.target_Q: target_Qs}
                loss, _ = sess.run([Q_NN_grad.loss, Q_NN_grad.opt], feed_dict)

                if ep_iter%update_nn_target==0:
                    update_values_sess(sess, assigns)

                if (len(training_rewards)>=100) and (np.array(training_rewards[-100:])>= 195).all():
                    print('Gym solved!')
                    print('Final Episode:', i)
                    return training_loss, training_rewards
    return training_loss, training_rewards

training_loss, training_rewards = train_agent()
# Out:
# Episode: 1 Total reward: 34.0000 Training loss: 1.0100 Epsilon: 0.9517
# Episode: 2 Total reward: 14.0000 Training loss: 0.9777 Epsilon: 0.9058
# Episode: 3 Total reward: 15.0000 Training loss: 1.0038 Epsilon: 0.8621
# Episode: 4 Total reward: 10.0000 Training loss: 1.0669 Epsilon: 0.8205
# Episode: 5 Total reward: 55.0000 Training loss: 1.1243 Epsilon: 0.7810
# Episode: 6 Total reward: 24.0000 Training loss: 1.3076 Epsilon: 0.7434
# Episode: 7 Total reward: 16.0000 Training loss: 1.2262 Epsilon: 0.7076
# Episode: 8 Total reward: 10.0000 Training loss: 1.2207 Epsilon: 0.6736
# Episode: 9 Total reward: 15.0000 Training loss: 1.5754 Epsilon: 0.6413
# Episode: 10 Total reward: 11.0000 Training loss: 1.6837 Epsilon: 0.6105
# Episode: 11 Total reward: 34.0000 Training loss: 1.8124 Epsilon: 0.5812
# Episode: 12 Total reward: 24.0000 Training loss: 2.9600 Epsilon: 0.5533
# Episode: 13 Total reward: 18.0000 Training loss: 1.9268 Epsilon: 0.5268
# Episode: 14 Total reward: 10.0000 Training loss: 1.7812 Epsilon: 0.5016
# Episode: 15 Total reward: 15.0000 Training loss: 3.0563 Epsilon: 0.4776
# Episode: 16 Total reward: 12.0000 Training loss: 2.5919 Epsilon: 0.4548
# Episode: 17 Total reward: 11.0000 Training loss: 2.6973 Epsilon: 0.4331
# Episode: 18 Total reward: 10.0000 Training loss: 5.3655 Epsilon: 0.4125
# Episode: 19 Total reward: 11.0000 Training loss: 3.1727 Epsilon: 0.3929
# Episode: 20 Total reward: 9.0000 Training loss: 6.9966 Epsilon: 0.3742
# Episode: 21 Total reward: 13.0000 Training loss: 5.9354 Epsilon: 0.3564
# Episode: 22 Total reward: 10.0000 Training loss: 5.8041 Epsilon: 0.3395
# Episode: 23 Total reward: 13.0000 Training loss: 11.3901 Epsilon: 0.3235
# Episode: 24 Total reward: 14.0000 Training loss: 4.3718 Epsilon: 0.3082
# Episode: 25 Total reward: 8.0000 Training loss: 14.1992 Epsilon: 0.2936
# Episode: 26 Total reward: 11.0000 Training loss: 26.7279 Epsilon: 0.2798
# Episode: 27 Total reward: 11.0000 Training loss: 11.6053 Epsilon: 0.2666
# Episode: 28 Total reward: 9.0000 Training loss: 16.1937 Epsilon: 0.2541
# Episode: 29 Total reward: 10.0000 Training loss: 20.6714 Epsilon: 0.2422
# Episode: 30 Total reward: 15.0000 Training loss: 15.9099 Epsilon: 0.2309
# Episode: 31 Total reward: 11.0000 Training loss: 7.6978 Epsilon: 0.2201
# Episode: 32 Total reward: 9.0000 Training loss: 29.3362 Epsilon: 0.2099
# Episode: 33 Total reward: 12.0000 Training loss: 23.1878 Epsilon: 0.2001
# Episode: 34 Total reward: 13.0000 Training loss: 17.3193 Epsilon: 0.1909
# Episode: 35 Total reward: 8.0000 Training loss: 25.3042 Epsilon: 0.1820
# Episode: 36 Total reward: 9.0000 Training loss: 26.8021 Epsilon: 0.1736
# Episode: 37 Total reward: 12.0000 Training loss: 8.3097 Epsilon: 0.1657
# Episode: 38 Total reward: 9.0000 Training loss: 12.1337 Epsilon: 0.1581
# Episode: 39 Total reward: 10.0000 Training loss: 34.8866 Epsilon: 0.1509
# Episode: 40 Total reward: 8.0000 Training loss: 10.4512 Epsilon: 0.1440
# Episode: 41 Total reward: 9.0000 Training loss: 16.6644 Epsilon: 0.1374
# Episode: 42 Total reward: 11.0000 Training loss: 27.7367 Epsilon: 0.1312
# Episode: 43 Total reward: 10.0000 Training loss: 58.7169 Epsilon: 0.1253
# Episode: 44 Total reward: 11.0000 Training loss: 16.0945 Epsilon: 0.1197
# Episode: 45 Total reward: 11.0000 Training loss: 40.6441 Epsilon: 0.1143
# Episode: 46 Total reward: 9.0000 Training loss: 23.8690 Epsilon: 0.1093
# Episode: 47 Total reward: 11.0000 Training loss: 9.1874 Epsilon: 0.1044
# Episode: 48 Total reward: 10.0000 Training loss: 43.4918 Epsilon: 0.0998
# Episode: 49 Total reward: 9.0000 Training loss: 17.6966 Epsilon: 0.0954
# Episode: 50 Total reward: 10.0000 Training loss: 41.7474 Epsilon: 0.0913
# Episode: 51 Total reward: 9.0000 Training loss: 47.7938 Epsilon: 0.0873
# Episode: 52 Total reward: 11.0000 Training loss: 38.2254 Epsilon: 0.0835
# Episode: 53 Total reward: 14.0000 Training loss: 9.7387 Epsilon: 0.0799
# Episode: 54 Total reward: 9.0000 Training loss: 19.6506 Epsilon: 0.0765
# Episode: 55 Total reward: 10.0000 Training loss: 30.2502 Epsilon: 0.0733
# Episode: 56 Total reward: 9.0000 Training loss: 35.5778 Epsilon: 0.0702
# Episode: 57 Total reward: 9.0000 Training loss: 14.1480 Epsilon: 0.0673
# Episode: 58 Total reward: 9.0000 Training loss: 31.5694 Epsilon: 0.0645
# Episode: 59 Total reward: 9.0000 Training loss: 27.3930 Epsilon: 0.0618
# Episode: 60 Total reward: 9.0000 Training loss: 15.7361 Epsilon: 0.0593
# Episode: 61 Total reward: 10.0000 Training loss: 14.9190 Epsilon: 0.0569
# Episode: 62 Total reward: 10.0000 Training loss: 11.2314 Epsilon: 0.0546
# Episode: 63 Total reward: 10.0000 Training loss: 29.9292 Epsilon: 0.0524
# Episode: 64 Total reward: 10.0000 Training loss: 3.7816 Epsilon: 0.0504
# Episode: 65 Total reward: 10.0000 Training loss: 57.8132 Epsilon: 0.0484
# Episode: 66 Total reward: 10.0000 Training loss: 11.6689 Epsilon: 0.0465
# Episode: 67 Total reward: 10.0000 Training loss: 18.4621 Epsilon: 0.0447
# Episode: 68 Total reward: 9.0000 Training loss: 37.2140 Epsilon: 0.0430
# Episode: 69 Total reward: 9.0000 Training loss: 26.0266 Epsilon: 0.0414
# Episode: 70 Total reward: 10.0000 Training loss: 10.9675 Epsilon: 0.0399
# Episode: 71 Total reward: 9.0000 Training loss: 17.8056 Epsilon: 0.0384
# Episode: 72 Total reward: 9.0000 Training loss: 51.3946 Epsilon: 0.0371
# Episode: 73 Total reward: 9.0000 Training loss: 23.8202 Epsilon: 0.0357
# Episode: 74 Total reward: 10.0000 Training loss: 9.9303 Epsilon: 0.0345
# Episode: 75 Total reward: 11.0000 Training loss: 25.0232 Epsilon: 0.0333
# Episode: 76 Total reward: 10.0000 Training loss: 15.1132 Epsilon: 0.0321
# Episode: 77 Total reward: 12.0000 Training loss: 14.7677 Epsilon: 0.0311
# Episode: 78 Total reward: 10.0000 Training loss: 29.6032 Epsilon: 0.0300
# Episode: 79 Total reward: 11.0000 Training loss: 11.0167 Epsilon: 0.0291
# Episode: 80 Total reward: 10.0000 Training loss: 6.4471 Epsilon: 0.0281
# Episode: 81 Total reward: 10.0000 Training loss: 29.7647 Epsilon: 0.0272
# Episode: 82 Total reward: 12.0000 Training loss: 12.4613 Epsilon: 0.0264
# Episode: 83 Total reward: 10.0000 Training loss: 12.2545 Epsilon: 0.0256
# Episode: 84 Total reward: 11.0000 Training loss: 10.0575 Epsilon: 0.0248
# Episode: 85 Total reward: 10.0000 Training loss: 23.5280 Epsilon: 0.0241
# Episode: 86 Total reward: 12.0000 Training loss: 13.3084 Epsilon: 0.0234
# Episode: 87 Total reward: 11.0000 Training loss: 9.2214 Epsilon: 0.0228
# Episode: 88 Total reward: 12.0000 Training loss: 17.0434 Epsilon: 0.0222
# Episode: 89 Total reward: 13.0000 Training loss: 12.3473 Epsilon: 0.0216
# Episode: 90 Total reward: 13.0000 Training loss: 5.8605 Epsilon: 0.0210
# Episode: 91 Total reward: 11.0000 Training loss: 9.0782 Epsilon: 0.0205
# Episode: 92 Total reward: 11.0000 Training loss: 28.9257 Epsilon: 0.0200
# Episode: 93 Total reward: 12.0000 Training loss: 12.3646 Epsilon: 0.0195
# Episode: 94 Total reward: 13.0000 Training loss: 12.4718 Epsilon: 0.0190
# Episode: 95 Total reward: 14.0000 Training loss: 8.8750 Epsilon: 0.0186
# Episode: 96 Total reward: 12.0000 Training loss: 9.0172 Epsilon: 0.0181
# Episode: 97 Total reward: 12.0000 Training loss: 15.4719 Epsilon: 0.0178
# Episode: 98 Total reward: 10.0000 Training loss: 4.8986 Epsilon: 0.0174
# Episode: 99 Total reward: 10.0000 Training loss: 14.7744 Epsilon: 0.0170
# Episode: 100 Total reward: 12.0000 Training loss: 8.4498 Epsilon: 0.0167
# Episode: 101 Total reward: 10.0000 Training loss: 16.0050 Epsilon: 0.0163
# Episode: 102 Total reward: 15.0000 Training loss: 12.0665 Epsilon: 0.0160
# Episode: 103 Total reward: 9.0000 Training loss: 5.0228 Epsilon: 0.0157
# Episode: 104 Total reward: 10.0000 Training loss: 4.9206 Epsilon: 0.0155
# Episode: 105 Total reward: 8.0000 Training loss: 7.1017 Epsilon: 0.0152
# Episode: 106 Total reward: 10.0000 Training loss: 5.9352 Epsilon: 0.0149
# Episode: 107 Total reward: 9.0000 Training loss: 8.3615 Epsilon: 0.0147
# Episode: 108 Total reward: 8.0000 Training loss: 9.6805 Epsilon: 0.0145
# Episode: 109 Total reward: 9.0000 Training loss: 1.5511 Epsilon: 0.0143
# Episode: 110 Total reward: 8.0000 Training loss: 10.6621 Epsilon: 0.0140
# Episode: 111 Total reward: 9.0000 Training loss: 5.3864 Epsilon: 0.0138
# Episode: 112 Total reward: 10.0000 Training loss: 15.2124 Epsilon: 0.0137
# Episode: 113 Total reward: 8.0000 Training loss: 4.8662 Epsilon: 0.0135
# Episode: 114 Total reward: 9.0000 Training loss: 12.4305 Epsilon: 0.0133
# Episode: 115 Total reward: 10.0000 Training loss: 6.6532 Epsilon: 0.0132
# Episode: 116 Total reward: 10.0000 Training loss: 29.2504 Epsilon: 0.0130
# Episode: 117 Total reward: 12.0000 Training loss: 5.0989 Epsilon: 0.0129
# Episode: 118 Total reward: 11.0000 Training loss: 6.2138 Epsilon: 0.0127
# Episode: 119 Total reward: 9.0000 Training loss: 7.0742 Epsilon: 0.0126
# Episode: 120 Total reward: 11.0000 Training loss: 9.8431 Epsilon: 0.0125
# Episode: 121 Total reward: 14.0000 Training loss: 8.7852 Epsilon: 0.0123
# Episode: 122 Total reward: 13.0000 Training loss: 25.2428 Epsilon: 0.0122
# Episode: 123 Total reward: 13.0000 Training loss: 3.6676 Epsilon: 0.0121
# Episode: 124 Total reward: 15.0000 Training loss: 5.6660 Epsilon: 0.0120
# Episode: 125 Total reward: 14.0000 Training loss: 19.6852 Epsilon: 0.0119
# Episode: 126 Total reward: 15.0000 Training loss: 23.7940 Epsilon: 0.0118
# Episode: 127 Total reward: 16.0000 Training loss: 8.9653 Epsilon: 0.0117
# Episode: 128 Total reward: 17.0000 Training loss: 3.9725 Epsilon: 0.0116
# Episode: 129 Total reward: 15.0000 Training loss: 10.0499 Epsilon: 0.0116
# Episode: 130 Total reward: 13.0000 Training loss: 7.2732 Epsilon: 0.0115
# Episode: 131 Total reward: 15.0000 Training loss: 15.1791 Epsilon: 0.0114
# Episode: 132 Total reward: 12.0000 Training loss: 1.5096 Epsilon: 0.0113
# Episode: 133 Total reward: 15.0000 Training loss: 18.0772 Epsilon: 0.0113
# Episode: 134 Total reward: 12.0000 Training loss: 8.4034 Epsilon: 0.0112
# Episode: 135 Total reward: 15.0000 Training loss: 8.3744 Epsilon: 0.0112
# Episode: 136 Total reward: 11.0000 Training loss: 8.0245 Epsilon: 0.0111
# Episode: 137 Total reward: 12.0000 Training loss: 14.5140 Epsilon: 0.0110
# Episode: 138 Total reward: 13.0000 Training loss: 10.4937 Epsilon: 0.0110
# Episode: 139 Total reward: 15.0000 Training loss: 21.5989 Epsilon: 0.0109
# Episode: 140 Total reward: 18.0000 Training loss: 24.5942 Epsilon: 0.0109
# Episode: 141 Total reward: 15.0000 Training loss: 11.4493 Epsilon: 0.0109
# Episode: 142 Total reward: 13.0000 Training loss: 6.6320 Epsilon: 0.0108
# Episode: 143 Total reward: 13.0000 Training loss: 1.8609 Epsilon: 0.0108
# Episode: 144 Total reward: 12.0000 Training loss: 7.9171 Epsilon: 0.0107
# Episode: 145 Total reward: 13.0000 Training loss: 12.0216 Epsilon: 0.0107
# Episode: 146 Total reward: 19.0000 Training loss: 34.6141 Epsilon: 0.0107
# Episode: 147 Total reward: 15.0000 Training loss: 27.9818 Epsilon: 0.0106
# Episode: 148 Total reward: 17.0000 Training loss: 4.3508 Epsilon: 0.0106
# Episode: 149 Total reward: 16.0000 Training loss: 4.5388 Epsilon: 0.0106
# Episode: 150 Total reward: 19.0000 Training loss: 9.2550 Epsilon: 0.0105
# Episode: 151 Total reward: 15.0000 Training loss: 6.4014 Epsilon: 0.0105
# Episode: 152 Total reward: 17.0000 Training loss: 18.7957 Epsilon: 0.0105
# Episode: 153 Total reward: 14.0000 Training loss: 12.4314 Epsilon: 0.0105
# Episode: 154 Total reward: 16.0000 Training loss: 18.8656 Epsilon: 0.0104
# Episode: 155 Total reward: 18.0000 Training loss: 10.4548 Epsilon: 0.0104
# Episode: 156 Total reward: 18.0000 Training loss: 8.1666 Epsilon: 0.0104
# Episode: 157 Total reward: 13.0000 Training loss: 6.8417 Epsilon: 0.0104
# Episode: 158 Total reward: 15.0000 Training loss: 16.6244 Epsilon: 0.0104
# Episode: 159 Total reward: 29.0000 Training loss: 13.1891 Epsilon: 0.0103
# Episode: 160 Total reward: 28.0000 Training loss: 2.8625 Epsilon: 0.0103
# Episode: 161 Total reward: 29.0000 Training loss: 19.7532 Epsilon: 0.0103
# Episode: 162 Total reward: 22.0000 Training loss: 10.9438 Epsilon: 0.0103
# Episode: 163 Total reward: 20.0000 Training loss: 11.6479 Epsilon: 0.0103
# Episode: 164 Total reward: 16.0000 Training loss: 19.0318 Epsilon: 0.0103
# Episode: 165 Total reward: 13.0000 Training loss: 6.0761 Epsilon: 0.0103
# Episode: 166 Total reward: 17.0000 Training loss: 8.8155 Epsilon: 0.0102
# Episode: 167 Total reward: 20.0000 Training loss: 0.9683 Epsilon: 0.0102
# Episode: 168 Total reward: 24.0000 Training loss: 30.3066 Epsilon: 0.0102
# Episode: 169 Total reward: 107.0000 Training loss: 5.4826 Epsilon: 0.0102
# Episode: 170 Total reward: 69.0000 Training loss: 16.9508 Epsilon: 0.0102
# Episode: 171 Total reward: 68.0000 Training loss: 4.9772 Epsilon: 0.0102
# Episode: 172 Total reward: 200.0000 Training loss: 6.0670 Epsilon: 0.0102
# Episode: 173 Total reward: 176.0000 Training loss: 32.2282 Epsilon: 0.0102
# Episode: 174 Total reward: 95.0000 Training loss: 15.5973 Epsilon: 0.0102
# Episode: 175 Total reward: 81.0000 Training loss: 38.5700 Epsilon: 0.0102
# Episode: 176 Total reward: 149.0000 Training loss: 13.7735 Epsilon: 0.0101
# Episode: 177 Total reward: 35.0000 Training loss: 5.0091 Epsilon: 0.0101
# Episode: 178 Total reward: 30.0000 Training loss: 36.3971 Epsilon: 0.0101
# Episode: 179 Total reward: 22.0000 Training loss: 13.4870 Epsilon: 0.0101
# Episode: 180 Total reward: 27.0000 Training loss: 42.3113 Epsilon: 0.0101
# Episode: 181 Total reward: 20.0000 Training loss: 24.5250 Epsilon: 0.0101
# Episode: 182 Total reward: 33.0000 Training loss: 11.7733 Epsilon: 0.0101
# Episode: 183 Total reward: 26.0000 Training loss: 19.6672 Epsilon: 0.0101
# Episode: 184 Total reward: 16.0000 Training loss: 62.3388 Epsilon: 0.0101
# Episode: 185 Total reward: 21.0000 Training loss: 10.2712 Epsilon: 0.0101
# Episode: 186 Total reward: 26.0000 Training loss: 71.8910 Epsilon: 0.0101
# Episode: 187 Total reward: 44.0000 Training loss: 3.6180 Epsilon: 0.0101
# Episode: 188 Total reward: 48.0000 Training loss: 140.1744 Epsilon: 0.0101
# Episode: 189 Total reward: 20.0000 Training loss: 68.0620 Epsilon: 0.0101
# Episode: 190 Total reward: 23.0000 Training loss: 4.8720 Epsilon: 0.0101
# Episode: 191 Total reward: 19.0000 Training loss: 45.6186 Epsilon: 0.0101
# Episode: 192 Total reward: 21.0000 Training loss: 30.5198 Epsilon: 0.0101
# Episode: 193 Total reward: 19.0000 Training loss: 3.1635 Epsilon: 0.0101
# Episode: 194 Total reward: 13.0000 Training loss: 49.6211 Epsilon: 0.0101
# Episode: 195 Total reward: 19.0000 Training loss: 10.5741 Epsilon: 0.0101
# Episode: 196 Total reward: 17.0000 Training loss: 136.1574 Epsilon: 0.0101
# Episode: 197 Total reward: 15.0000 Training loss: 46.8359 Epsilon: 0.0101
# Episode: 198 Total reward: 20.0000 Training loss: 14.1752 Epsilon: 0.0100
# Episode: 199 Total reward: 13.0000 Training loss: 28.4515 Epsilon: 0.0100
# Episode: 200 Total reward: 15.0000 Training loss: 2.5440 Epsilon: 0.0100
# Episode: 201 Total reward: 12.0000 Training loss: 54.9796 Epsilon: 0.0100
# Episode: 202 Total reward: 19.0000 Training loss: 53.6927 Epsilon: 0.0100
# Episode: 203 Total reward: 19.0000 Training loss: 9.4817 Epsilon: 0.0100
# Episode: 204 Total reward: 18.0000 Training loss: 6.6014 Epsilon: 0.0100
# Episode: 205 Total reward: 12.0000 Training loss: 72.5915 Epsilon: 0.0100
# Episode: 206 Total reward: 11.0000 Training loss: 8.9791 Epsilon: 0.0100
# Episode: 207 Total reward: 10.0000 Training loss: 30.8646 Epsilon: 0.0100
# Episode: 208 Total reward: 10.0000 Training loss: 61.8138 Epsilon: 0.0100
# Episode: 209 Total reward: 9.0000 Training loss: 4.9391 Epsilon: 0.0100
# Episode: 210 Total reward: 13.0000 Training loss: 16.5526 Epsilon: 0.0100
# Episode: 211 Total reward: 13.0000 Training loss: 20.1080 Epsilon: 0.0100
# Episode: 212 Total reward: 14.0000 Training loss: 110.3645 Epsilon: 0.0100
# Episode: 213 Total reward: 15.0000 Training loss: 4.4993 Epsilon: 0.0100
# Episode: 214 Total reward: 13.0000 Training loss: 69.2059 Epsilon: 0.0100
# Episode: 215 Total reward: 10.0000 Training loss: 13.5955 Epsilon: 0.0100
# Episode: 216 Total reward: 14.0000 Training loss: 43.1820 Epsilon: 0.0100
# Episode: 217 Total reward: 14.0000 Training loss: 3.5423 Epsilon: 0.0100
# Episode: 218 Total reward: 12.0000 Training loss: 24.0149 Epsilon: 0.0100
# Episode: 219 Total reward: 18.0000 Training loss: 63.6338 Epsilon: 0.0100
# Episode: 220 Total reward: 12.0000 Training loss: 114.1543 Epsilon: 0.0100
# Episode: 221 Total reward: 12.0000 Training loss: 4.2670 Epsilon: 0.0100
# Episode: 222 Total reward: 14.0000 Training loss: 86.7754 Epsilon: 0.0100
# Episode: 223 Total reward: 15.0000 Training loss: 95.6717 Epsilon: 0.0100
# Episode: 224 Total reward: 15.0000 Training loss: 103.7052 Epsilon: 0.0100
# Episode: 225 Total reward: 15.0000 Training loss: 26.0140 Epsilon: 0.0100
# Episode: 226 Total reward: 19.0000 Training loss: 111.8154 Epsilon: 0.0100
# Episode: 227 Total reward: 13.0000 Training loss: 186.8504 Epsilon: 0.0100
# Episode: 228 Total reward: 16.0000 Training loss: 65.1107 Epsilon: 0.0100
# Episode: 229 Total reward: 14.0000 Training loss: 61.9357 Epsilon: 0.0100
# Episode: 230 Total reward: 17.0000 Training loss: 27.2208 Epsilon: 0.0100
# Episode: 231 Total reward: 20.0000 Training loss: 66.3351 Epsilon: 0.0100
# Episode: 232 Total reward: 17.0000 Training loss: 119.5568 Epsilon: 0.0100
# Episode: 233 Total reward: 15.0000 Training loss: 3.6396 Epsilon: 0.0100
# Episode: 234 Total reward: 14.0000 Training loss: 186.9587 Epsilon: 0.0100
# Episode: 235 Total reward: 14.0000 Training loss: 72.4568 Epsilon: 0.0100
# Episode: 236 Total reward: 18.0000 Training loss: 194.2301 Epsilon: 0.0100
# Episode: 237 Total reward: 13.0000 Training loss: 10.7918 Epsilon: 0.0100
# Episode: 238 Total reward: 11.0000 Training loss: 89.7058 Epsilon: 0.0100
# Episode: 239 Total reward: 14.0000 Training loss: 106.6184 Epsilon: 0.0100
# Episode: 240 Total reward: 11.0000 Training loss: 24.0616 Epsilon: 0.0100
# Episode: 241 Total reward: 14.0000 Training loss: 4.4077 Epsilon: 0.0100
# Episode: 242 Total reward: 11.0000 Training loss: 18.7173 Epsilon: 0.0100
# Episode: 243 Total reward: 14.0000 Training loss: 121.0851 Epsilon: 0.0100
# Episode: 244 Total reward: 13.0000 Training loss: 29.7423 Epsilon: 0.0100
# Episode: 245 Total reward: 17.0000 Training loss: 21.9406 Epsilon: 0.0100
# Episode: 246 Total reward: 14.0000 Training loss: 4.8566 Epsilon: 0.0100
# Episode: 247 Total reward: 15.0000 Training loss: 12.7454 Epsilon: 0.0100
# Episode: 248 Total reward: 27.0000 Training loss: 76.5709 Epsilon: 0.0100
# Episode: 249 Total reward: 17.0000 Training loss: 195.2027 Epsilon: 0.0100
# Episode: 250 Total reward: 20.0000 Training loss: 83.6772 Epsilon: 0.0100
# Episode: 251 Total reward: 19.0000 Training loss: 56.4501 Epsilon: 0.0100
# Episode: 252 Total reward: 18.0000 Training loss: 59.2017 Epsilon: 0.0100
# Episode: 253 Total reward: 19.0000 Training loss: 2.3390 Epsilon: 0.0100
# Episode: 254 Total reward: 18.0000 Training loss: 3.7445 Epsilon: 0.0100
# Episode: 255 Total reward: 17.0000 Training loss: 56.5570 Epsilon: 0.0100
# Episode: 256 Total reward: 27.0000 Training loss: 116.2145 Epsilon: 0.0100
# Episode: 257 Total reward: 19.0000 Training loss: 57.6980 Epsilon: 0.0100
# Episode: 258 Total reward: 17.0000 Training loss: 52.6449 Epsilon: 0.0100
# Episode: 259 Total reward: 21.0000 Training loss: 23.1595 Epsilon: 0.0100
# Episode: 260 Total reward: 24.0000 Training loss: 69.3965 Epsilon: 0.0100
# Episode: 261 Total reward: 24.0000 Training loss: 237.6168 Epsilon: 0.0100
# Episode: 262 Total reward: 29.0000 Training loss: 10.2119 Epsilon: 0.0100
# Episode: 263 Total reward: 38.0000 Training loss: 60.4100 Epsilon: 0.0100
# Episode: 264 Total reward: 47.0000 Training loss: 20.2901 Epsilon: 0.0100
# Episode: 265 Total reward: 32.0000 Training loss: 66.8903 Epsilon: 0.0100
# Episode: 266 Total reward: 20.0000 Training loss: 14.9567 Epsilon: 0.0100
# Episode: 267 Total reward: 34.0000 Training loss: 19.6493 Epsilon: 0.0100
# Episode: 268 Total reward: 33.0000 Training loss: 33.9192 Epsilon: 0.0100
# Episode: 269 Total reward: 25.0000 Training loss: 37.4856 Epsilon: 0.0100
# Episode: 270 Total reward: 27.0000 Training loss: 45.4292 Epsilon: 0.0100
# Episode: 271 Total reward: 19.0000 Training loss: 2.3738 Epsilon: 0.0100
# Episode: 272 Total reward: 21.0000 Training loss: 44.5806 Epsilon: 0.0100
# Episode: 273 Total reward: 23.0000 Training loss: 3.3457 Epsilon: 0.0100
# Episode: 274 Total reward: 26.0000 Training loss: 30.0529 Epsilon: 0.0100
# Episode: 275 Total reward: 19.0000 Training loss: 5.1599 Epsilon: 0.0100
# Episode: 276 Total reward: 31.0000 Training loss: 46.1346 Epsilon: 0.0100
# Episode: 277 Total reward: 22.0000 Training loss: 151.6941 Epsilon: 0.0100
# Episode: 278 Total reward: 22.0000 Training loss: 43.4054 Epsilon: 0.0100
# Episode: 279 Total reward: 20.0000 Training loss: 89.9633 Epsilon: 0.0100
# Episode: 280 Total reward: 55.0000 Training loss: 2.5295 Epsilon: 0.0100
# Episode: 281 Total reward: 38.0000 Training loss: 68.6919 Epsilon: 0.0100
# Episode: 282 Total reward: 71.0000 Training loss: 43.8153 Epsilon: 0.0100
# Episode: 283 Total reward: 40.0000 Training loss: 72.1474 Epsilon: 0.0100
# Episode: 284 Total reward: 70.0000 Training loss: 56.2820 Epsilon: 0.0100
# Episode: 285 Total reward: 46.0000 Training loss: 3.5750 Epsilon: 0.0100
# Episode: 286 Total reward: 46.0000 Training loss: 2.7508 Epsilon: 0.0100
# Episode: 287 Total reward: 44.0000 Training loss: 27.4012 Epsilon: 0.0100
# Episode: 288 Total reward: 57.0000 Training loss: 16.0028 Epsilon: 0.0100
# Episode: 289 Total reward: 73.0000 Training loss: 16.3697 Epsilon: 0.0100
# Episode: 290 Total reward: 60.0000 Training loss: 18.7683 Epsilon: 0.0100
# Episode: 291 Total reward: 80.0000 Training loss: 21.4728 Epsilon: 0.0100
# Episode: 292 Total reward: 81.0000 Training loss: 5.2367 Epsilon: 0.0100
# Episode: 293 Total reward: 155.0000 Training loss: 21.8879 Epsilon: 0.0100
# Episode: 294 Total reward: 108.0000 Training loss: 14.1803 Epsilon: 0.0100
# Episode: 295 Total reward: 49.0000 Training loss: 47.7497 Epsilon: 0.0100
# Episode: 296 Total reward: 62.0000 Training loss: 2.1153 Epsilon: 0.0100
# Episode: 297 Total reward: 45.0000 Training loss: 4.2022 Epsilon: 0.0100
# Episode: 298 Total reward: 89.0000 Training loss: 68.2593 Epsilon: 0.0100
# Episode: 299 Total reward: 109.0000 Training loss: 2.6862 Epsilon: 0.0100
# Episode: 300 Total reward: 153.0000 Training loss: 20.8381 Epsilon: 0.0100
# Episode: 301 Total reward: 123.0000 Training loss: 44.4273 Epsilon: 0.0100
# Episode: 302 Total reward: 99.0000 Training loss: 23.3042 Epsilon: 0.0100
# Episode: 303 Total reward: 137.0000 Training loss: 116.7606 Epsilon: 0.0100
# Episode: 304 Total reward: 60.0000 Training loss: 3.2484 Epsilon: 0.0100
# Episode: 305 Total reward: 43.0000 Training loss: 117.1945 Epsilon: 0.0100
# Episode: 306 Total reward: 84.0000 Training loss: 61.5184 Epsilon: 0.0100
# Episode: 307 Total reward: 113.0000 Training loss: 37.2856 Epsilon: 0.0100
# Episode: 308 Total reward: 103.0000 Training loss: 88.1934 Epsilon: 0.0100
# Episode: 309 Total reward: 171.0000 Training loss: 5.4434 Epsilon: 0.0100
# Episode: 310 Total reward: 110.0000 Training loss: 3.8389 Epsilon: 0.0100
# Episode: 311 Total reward: 72.0000 Training loss: 2.1771 Epsilon: 0.0100
# Episode: 312 Total reward: 111.0000 Training loss: 55.1625 Epsilon: 0.0100
# Episode: 313 Total reward: 97.0000 Training loss: 71.8947 Epsilon: 0.0100
# Episode: 314 Total reward: 87.0000 Training loss: 4.2879 Epsilon: 0.0100
# Episode: 315 Total reward: 89.0000 Training loss: 2.8881 Epsilon: 0.0100
# Episode: 316 Total reward: 143.0000 Training loss: 3.0146 Epsilon: 0.0100
# Episode: 317 Total reward: 126.0000 Training loss: 120.4670 Epsilon: 0.0100
# Episode: 318 Total reward: 188.0000 Training loss: 46.4826 Epsilon: 0.0100
# Episode: 319 Total reward: 143.0000 Training loss: 3.5384 Epsilon: 0.0100
# Episode: 320 Total reward: 154.0000 Training loss: 3.3062 Epsilon: 0.0100
# Episode: 321 Total reward: 195.0000 Training loss: 15.2484 Epsilon: 0.0100
# Episode: 322 Total reward: 120.0000 Training loss: 3.9562 Epsilon: 0.0100
# Episode: 323 Total reward: 190.0000 Training loss: 7.9979 Epsilon: 0.0100
# Episode: 324 Total reward: 118.0000 Training loss: 3.1859 Epsilon: 0.0100
# Episode: 325 Total reward: 166.0000 Training loss: 16.5550 Epsilon: 0.0100
# Episode: 326 Total reward: 82.0000 Training loss: 123.1676 Epsilon: 0.0100
# Episode: 327 Total reward: 131.0000 Training loss: 10.3282 Epsilon: 0.0100
# Episode: 328 Total reward: 156.0000 Training loss: 3.8362 Epsilon: 0.0100
# Episode: 329 Total reward: 200.0000 Training loss: 5.5060 Epsilon: 0.0100
# Episode: 330 Total reward: 200.0000 Training loss: 5.2109 Epsilon: 0.0100
# Episode: 331 Total reward: 159.0000 Training loss: 4.7774 Epsilon: 0.0100
# Episode: 332 Total reward: 197.0000 Training loss: 3.4998 Epsilon: 0.0100
# Episode: 333 Total reward: 167.0000 Training loss: 70.4388 Epsilon: 0.0100
# Episode: 334 Total reward: 138.0000 Training loss: 2.7393 Epsilon: 0.0100
# Episode: 335 Total reward: 193.0000 Training loss: 4.6902 Epsilon: 0.0100
# Episode: 336 Total reward: 144.0000 Training loss: 126.6081 Epsilon: 0.0100
# Episode: 337 Total reward: 170.0000 Training loss: 132.2899 Epsilon: 0.0100
# Episode: 338 Total reward: 190.0000 Training loss: 6.1678 Epsilon: 0.0100
# Episode: 339 Total reward: 110.0000 Training loss: 182.7668 Epsilon: 0.0100
# Episode: 340 Total reward: 121.0000 Training loss: 85.4911 Epsilon: 0.0100
# Episode: 341 Total reward: 196.0000 Training loss: 94.2373 Epsilon: 0.0100
# Episode: 342 Total reward: 200.0000 Training loss: 6.0033 Epsilon: 0.0100
# Episode: 343 Total reward: 200.0000 Training loss: 112.5290 Epsilon: 0.0100
# Episode: 344 Total reward: 200.0000 Training loss: 99.5498 Epsilon: 0.0100
# Episode: 345 Total reward: 200.0000 Training loss: 91.5320 Epsilon: 0.0100
# Episode: 346 Total reward: 200.0000 Training loss: 96.4195 Epsilon: 0.0100
# Episode: 347 Total reward: 200.0000 Training loss: 3.7031 Epsilon: 0.0100
# Episode: 348 Total reward: 200.0000 Training loss: 106.5267 Epsilon: 0.0100
# Episode: 349 Total reward: 200.0000 Training loss: 7.4523 Epsilon: 0.0100
# Episode: 350 Total reward: 200.0000 Training loss: 3.4389 Epsilon: 0.0100
# Episode: 351 Total reward: 200.0000 Training loss: 5.1102 Epsilon: 0.0100
# Episode: 352 Total reward: 200.0000 Training loss: 212.4267 Epsilon: 0.0100
# Episode: 353 Total reward: 200.0000 Training loss: 14.5109 Epsilon: 0.0100
# Episode: 354 Total reward: 200.0000 Training loss: 246.8339 Epsilon: 0.0100
# Episode: 355 Total reward: 200.0000 Training loss: 47.2921 Epsilon: 0.0100
# Episode: 356 Total reward: 200.0000 Training loss: 161.2745 Epsilon: 0.0100
# Episode: 357 Total reward: 200.0000 Training loss: 5.5652 Epsilon: 0.0100
# Episode: 358 Total reward: 200.0000 Training loss: 353.6519 Epsilon: 0.0100
# Episode: 359 Total reward: 200.0000 Training loss: 13.6134 Epsilon: 0.0100
# Episode: 360 Total reward: 200.0000 Training loss: 9.5424 Epsilon: 0.0100
# Episode: 361 Total reward: 200.0000 Training loss: 8.4315 Epsilon: 0.0100
# Episode: 362 Total reward: 200.0000 Training loss: 10.0549 Epsilon: 0.0100
# Episode: 363 Total reward: 200.0000 Training loss: 342.5220 Epsilon: 0.0100
# Episode: 364 Total reward: 200.0000 Training loss: 6.3255 Epsilon: 0.0100
# Episode: 365 Total reward: 200.0000 Training loss: 589.8669 Epsilon: 0.0100
# Episode: 366 Total reward: 200.0000 Training loss: 9.2349 Epsilon: 0.0100
# Episode: 367 Total reward: 200.0000 Training loss: 9.2097 Epsilon: 0.0100
# Episode: 368 Total reward: 200.0000 Training loss: 5.9657 Epsilon: 0.0100
# Episode: 369 Total reward: 200.0000 Training loss: 8.6811 Epsilon: 0.0100
# Episode: 370 Total reward: 200.0000 Training loss: 485.5375 Epsilon: 0.0100
# Episode: 371 Total reward: 200.0000 Training loss: 15.3066 Epsilon: 0.0100
# Episode: 372 Total reward: 200.0000 Training loss: 9.2381 Epsilon: 0.0100
# Episode: 373 Total reward: 200.0000 Training loss: 8.3802 Epsilon: 0.0100
# Episode: 374 Total reward: 200.0000 Training loss: 367.2155 Epsilon: 0.0100
# Episode: 375 Total reward: 200.0000 Training loss: 258.4144 Epsilon: 0.0100
# Episode: 376 Total reward: 200.0000 Training loss: 12.7240 Epsilon: 0.0100
# Episode: 377 Total reward: 200.0000 Training loss: 16.6907 Epsilon: 0.0100
# Episode: 378 Total reward: 200.0000 Training loss: 14.4823 Epsilon: 0.0100
# Episode: 379 Total reward: 200.0000 Training loss: 15.1733 Epsilon: 0.0100
# Episode: 380 Total reward: 200.0000 Training loss: 410.5574 Epsilon: 0.0100
# Episode: 381 Total reward: 200.0000 Training loss: 238.0956 Epsilon: 0.0100
# Episode: 382 Total reward: 200.0000 Training loss: 959.8077 Epsilon: 0.0100
# Episode: 383 Total reward: 200.0000 Training loss: 21.6670 Epsilon: 0.0100
# Episode: 384 Total reward: 200.0000 Training loss: 185.9634 Epsilon: 0.0100
# Episode: 385 Total reward: 200.0000 Training loss: 621.6276 Epsilon: 0.0100
# Episode: 386 Total reward: 200.0000 Training loss: 296.5424 Epsilon: 0.0100
# Episode: 387 Total reward: 200.0000 Training loss: 29.8081 Epsilon: 0.0100
# Episode: 388 Total reward: 200.0000 Training loss: 9.2910 Epsilon: 0.0100
# Episode: 389 Total reward: 200.0000 Training loss: 191.2425 Epsilon: 0.0100
# Episode: 390 Total reward: 200.0000 Training loss: 20.4389 Epsilon: 0.0100
# Episode: 391 Total reward: 200.0000 Training loss: 10.4670 Epsilon: 0.0100
# Episode: 392 Total reward: 200.0000 Training loss: 320.0346 Epsilon: 0.0100
# Episode: 393 Total reward: 200.0000 Training loss: 17.2651 Epsilon: 0.0100
# Episode: 394 Total reward: 200.0000 Training loss: 29.2362 Epsilon: 0.0100
# Episode: 395 Total reward: 200.0000 Training loss: 23.5893 Epsilon: 0.0100
# Episode: 396 Total reward: 200.0000 Training loss: 14.5466 Epsilon: 0.0100
# Episode: 397 Total reward: 200.0000 Training loss: 1172.6813 Epsilon: 0.0100
# Episode: 398 Total reward: 200.0000 Training loss: 416.6935 Epsilon: 0.0100
# Episode: 399 Total reward: 200.0000 Training loss: 11.2866 Epsilon: 0.0100
# Episode: 400 Total reward: 200.0000 Training loss: 19.7847 Epsilon: 0.0100
# Episode: 401 Total reward: 200.0000 Training loss: 13.9499 Epsilon: 0.0100
# Episode: 402 Total reward: 200.0000 Training loss: 17.2408 Epsilon: 0.0100
# Episode: 403 Total reward: 200.0000 Training loss: 30.0953 Epsilon: 0.0100
# Episode: 404 Total reward: 200.0000 Training loss: 21.2682 Epsilon: 0.0100
# Episode: 405 Total reward: 200.0000 Training loss: 15.4642 Epsilon: 0.0100
# Episode: 406 Total reward: 200.0000 Training loss: 17.9574 Epsilon: 0.0100
# Episode: 407 Total reward: 200.0000 Training loss: 484.8857 Epsilon: 0.0100
# Episode: 408 Total reward: 200.0000 Training loss: 53.7558 Epsilon: 0.0100
# Episode: 409 Total reward: 200.0000 Training loss: 925.6378 Epsilon: 0.0100
# Episode: 410 Total reward: 200.0000 Training loss: 185.9396 Epsilon: 0.0100
# Episode: 411 Total reward: 200.0000 Training loss: 29.6970 Epsilon: 0.0100
# Episode: 412 Total reward: 200.0000 Training loss: 35.9820 Epsilon: 0.0100
# Episode: 413 Total reward: 200.0000 Training loss: 1446.4432 Epsilon: 0.0100
# Episode: 414 Total reward: 200.0000 Training loss: 33.6035 Epsilon: 0.0100
# Episode: 415 Total reward: 200.0000 Training loss: 23.8347 Epsilon: 0.0100
# Episode: 416 Total reward: 200.0000 Training loss: 1595.2140 Epsilon: 0.0100
# Episode: 417 Total reward: 200.0000 Training loss: 489.5761 Epsilon: 0.0100
# Episode: 418 Total reward: 200.0000 Training loss: 44.9459 Epsilon: 0.0100
# Episode: 419 Total reward: 200.0000 Training loss: 20.3950 Epsilon: 0.0100
# Episode: 420 Total reward: 200.0000 Training loss: 15.4184 Epsilon: 0.0100
# Episode: 421 Total reward: 200.0000 Training loss: 33.8376 Epsilon: 0.0100
# Episode: 422 Total reward: 200.0000 Training loss: 25.2418 Epsilon: 0.0100
# Episode: 423 Total reward: 200.0000 Training loss: 19.0726 Epsilon: 0.0100
# Episode: 424 Total reward: 200.0000 Training loss: 564.2596 Epsilon: 0.0100
# Episode: 425 Total reward: 200.0000 Training loss: 1737.5891 Epsilon: 0.0100
# Episode: 426 Total reward: 200.0000 Training loss: 6.2329 Epsilon: 0.0100
# Episode: 427 Total reward: 200.0000 Training loss: 726.7962 Epsilon: 0.0100
# Episode: 428 Total reward: 200.0000 Training loss: 459.3552 Epsilon: 0.0100
# Episode: 429 Total reward: 200.0000 Training loss: 45.1573 Epsilon: 0.0100
# Episode: 430 Total reward: 200.0000 Training loss: 2063.0928 Epsilon: 0.0100
# Episode: 431 Total reward: 200.0000 Training loss: 23.5463 Epsilon: 0.0100
# Episode: 432 Total reward: 200.0000 Training loss: 1356.8344 Epsilon: 0.0100
# Episode: 433 Total reward: 200.0000 Training loss: 20.1889 Epsilon: 0.0100
# Episode: 434 Total reward: 200.0000 Training loss: 7.9079 Epsilon: 0.0100
# Episode: 435 Total reward: 200.0000 Training loss: 1974.8915 Epsilon: 0.0100
# Episode: 436 Total reward: 200.0000 Training loss: 27.5553 Epsilon: 0.0100
# Episode: 437 Total reward: 200.0000 Training loss: 3229.4373 Epsilon: 0.0100
# Episode: 438 Total reward: 200.0000 Training loss: 23.4167 Epsilon: 0.0100
# Episode: 439 Total reward: 200.0000 Training loss: 2178.5540 Epsilon: 0.0100
# Episode: 440 Total reward: 200.0000 Training loss: 592.3739 Epsilon: 0.0100
# Gym solved!
# Final Episode: 440

# %%
from matplotlib import rcParams
rcParams["figure.figsize"] = 20, 10

def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / N 

eps, rews = np.array(training_rewards).T
smoothed_rews = running_mean(rews, 10)
plt.plot(eps[-len(smoothed_rews):], smoothed_rews)
plt.plot(eps, rews, color='blue', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.show()

# %%
eps, loss = np.array(training_loss).T
plt.plot(loss, color='blue')
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.show()
