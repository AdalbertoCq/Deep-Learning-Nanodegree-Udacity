# %%
import pandas as pd
import numpy as  np
import math
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from IPython.display import display, HTML
# %matplotlib inline

# Standard parameters for the plot.
mpl.rcParams["figure.figsize"] = 20, 20
mpl.rcParams['legend.fontsize'] = 20


def read_episode(episode_csv):
    episode = pd.read_csv(episode_csv)
    return episode

def plot_episode(episode_data, episode):
    display(episode_data)
    
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    x = episode_data['x']
    y = episode_data['y']
    z = episode_data['z']
    ax.plot(x, y, z, linewidth=3, label='Quadcopter Movement')
    ax.set_title('Episode %s' % episode, fontsize=25)
    ax.set_xlabel('X', fontsize=20)
    ax.set_ylabel('Y', fontsize=20)
    ax.set_xim([-5,5])
    ax.set_zim([0,10])
    ax.legend()
    
def plot_episodes(file_path, number_episodes, total, scale):
    if number_episodes==1:
        number_episodes+=1
    
    episodes = np.linspace(1, total, number_episodes, endpoint=True, dtype='int')
    if number_episodes==1:
        episodes = episodes[1:]
    
    # Redifine parameters depending on the number of plots.
    fig = plt.figure()
    
    rc = math.ceil(len(episodes)/2)
    
    for index, episode in enumerate(episodes):
        episode_csv = '%s/data_episode_%s.csv' % (file_path, episode)
        episode_data = read_episode(episode_csv)
        
#        ax = fig.add_subplot(len(episodes), 1, index+1, projection='3d')
        ax = fig.add_subplot(rc, rc, index+1, projection='3d')
        x = episode_data['x']
        y = episode_data['y']
        z = episode_data['z']
#        ax.plot(x, y, z, linewidth=3, label='Quadcopter Movement')
        ax.plot(x, y, z, linewidth=3)
        ax.set_title('Episode %s' % episode, fontsize=15)
        ax.set_xlabel('X', fontsize=15)
        ax.set_ylabel('Y', fontsize=15)
        ax.set_xlim(scale[0])
        ax.set_ylim(scale[1])
        ax.set_zlim(scale[2])
#        ax.legend()

# %%
file_path = "./data_quadcopter/takeoff"
number_episodes = 10
total = 200
scale = [[-20,20], [-20,20], [0,20]]

plot_episodes(file_path, number_episodes, total, scale)

# %%
episode = 120
episode_csv = '%s/data_episode_%s.csv' % (file_path, episode)
read_episode(episode_csv)
# Out:
#     time         x         y          z       phi     theta  psi  x_velocity  \
# 0   0.00  0.000000  0.000000   0.000000  0.000000  0.000000  0.0    0.000000
# 1   0.06 -0.000013  0.000020   0.023130  0.000449  0.003113  0.0   -0.000871
# 2   0.12 -0.000245  0.000059   0.092447  6.275724  0.011657  0.0   -0.008411
# 3   0.18 -0.001940 -0.000913   0.253244  6.258488  0.024369  0.0   -0.053138
# 4   0.24 -0.007438 -0.005608   0.549347  6.239112  0.040854  0.0   -0.136485
# 5   0.30 -0.019300 -0.017111   0.976950  6.217586  0.061120  0.0   -0.266298
# 6   0.36 -0.040499 -0.038618   1.530547  6.193898  0.085184  0.0   -0.448407
# 7   0.42 -0.074292 -0.073318   2.203165  6.168035  0.113062  0.0   -0.686537
# 8   0.48 -0.124104 -0.124294   2.986670  6.139992  0.144749  0.0   -0.982464
# 9   0.54 -0.193412 -0.194437   3.872093  6.109784  0.180222  0.0   -1.336313
# 10  0.60 -0.285666 -0.286394   4.849964  6.077448  0.219452  0.0   -1.747135
# 11  0.66 -0.404248 -0.402537   5.910649  6.043047  0.262364  0.0   -2.213704
# 12  0.72 -0.552464 -0.544964   7.044610  6.006690  0.308840  0.0   -2.734741
# 13  0.78 -0.733566 -0.715511   8.242616  5.968493  0.358678  0.0   -3.309894
# 14  0.84 -0.950812 -0.915790   9.495899  5.928623  0.411600  0.0   -3.939638
# 15  0.90 -1.207520 -1.147216  10.796212  5.887266  0.467275  0.0   -4.625518
# 16  0.96 -1.507114 -1.411014  12.135806  5.844625  0.525359  0.0   -5.369515
# 17  1.02 -1.853160 -1.708217  13.507370  5.800894  0.585505  0.0   -6.174288
# 18  1.08 -2.249377 -2.039633  14.903942  5.756273  0.647361  0.0   -7.042170
# 19  1.14 -2.699600 -2.405786  16.318790  5.710945  0.710605  0.0   -7.974708
# 20  1.20 -3.207732 -2.806845  17.745325  5.665067  0.774939  0.0   -8.972437
# 21  1.26 -3.777660 -3.242543  19.177030  5.618786  0.840074  0.0  -10.034261
#
#     y_velocity  z_velocity    ...      y_accel    z_accel  phi_velocity  \
# 0     0.000000    0.000000    ...     0.000000   0.000000      0.000000
# 1     0.001046    0.770796    ...     0.027846  12.838498     -0.139363
# 2    -0.001075    1.539072    ...    -0.087869  12.776768     -0.278893
# 3    -0.038427    3.816047    ...    -0.890342  37.759901     -0.314540
# 4    -0.125701    6.044674    ...    -1.742497  36.782987     -0.350348
# 5    -0.265664    8.195158    ...    -2.630126  35.323720     -0.386342
# 6    -0.459150   10.240841    ...    -3.520994  33.441868     -0.422562
# 7    -0.705162   12.159630    ...    -4.385725  31.219077     -0.458937
# 8    -1.001175   13.934943    ...    -5.200692  28.750337     -0.495080
# 9    -1.343462   15.555609    ...    -5.948226  26.126601     -0.530686
# 10   -1.727585   17.016056    ...    -6.619102  23.439286     -0.565354
# 11   -2.148982   18.316262    ...    -7.213786  20.776634     -0.598242
# 12   -2.603027   19.459312    ...    -7.732928  18.185454     -0.629341
# 13   -3.085740   20.452176    ...    -8.188668  15.723222     -0.657774
# 14   -3.593578   21.303122    ...    -8.588036  13.405021     -0.683256
# 15   -4.123469   22.021064    ...    -8.937824  11.234968     -0.705329
# 16   -4.672183   22.613631    ...    -9.233425   9.187210     -0.724310
# 17   -5.236403   23.087642    ...    -9.471130   7.244360     -0.739926
# 18   -5.811943   23.447862    ...    -9.634004   5.371268     -0.752430
# 19   -6.393462   23.697262    ...    -9.701029   3.538859     -0.762304
# 20   -6.974406   23.837610    ...    -9.651014   1.728912     -0.769711
# 21   -7.546793   23.869699    ...    -9.460103  -0.071429     -0.774839
#
#     theta_velocity  psi_velocity  rotor_speed1  rotor_speed2  rotor_speed3  \
# 0         0.000000           0.0     607.28920     612.61960     621.98883
# 1         0.089264           0.0     607.32710     612.75256     622.14594
# 2         0.179985           0.0     891.73676     894.31450     895.72906
# 3         0.242759           0.0     891.65650     894.25415     895.68304
# 4         0.305656           0.0     891.56464     894.18880     895.63403
# 5         0.368732           0.0     891.45190     894.11224     895.57733
# 6         0.432114           0.0     891.35394     894.05320     895.53534
# 7         0.495760           0.0     891.33890     894.06030     895.54400
# 8         0.559156           0.0     891.37340     894.11270     895.58600
# 9         0.622097           0.0     891.46936     894.22940     895.67900
# 10        0.684561           0.0     891.76290     894.49920     895.89770
# 11        0.745382           0.0     892.06635     894.76227     896.11250
# 12        0.804085           0.0     892.57870     895.15216     896.42430
# 13        0.858633           0.0     893.19006     895.60490     896.78723
# 14        0.908155           0.0     893.93005     896.13820     897.21040
# 15        0.951528           0.0     894.60220     896.61664     897.58690
# 16        0.989155           0.0     895.31195     897.10956     897.96735
# 17        1.020569           0.0     895.95807     897.54690     898.29944
# 18        1.046091           0.0     896.50080     897.90520     898.56820
# 19        1.066446           0.0     897.01020     898.22950     898.80756
# 20        1.081738           0.0     897.48303     898.52527     899.02240
# 21        1.092294           0.0     897.95230     898.81460     899.22670
#
#     rotor_speed4    reward
# 0      613.77246  0.000000
# 1      613.89905  2.571685
# 2      894.23910  2.572840
# 3      894.17510  2.575476
# 4      894.10580  2.580797
# 5      894.02550  2.588869
# 6      893.96140  2.599535
# 7      893.96240  2.612601
# 8      894.00793  2.627844
# 9      894.11993  2.645024
# 10     894.39150  2.663886
# 11     894.65936  2.684174
# 12     895.06040  2.705637
# 13     895.52515  2.728029
# 14     896.07010  2.751116
# 15     896.55725  2.774677
# 16     897.06134  2.798503
# 17     897.50880  2.822394
# 18     897.87537  2.846160
# 19     898.20776  2.869617
# 20     898.50980  2.892587
# 21     898.80290  2.914898
#
# [22 rows x 21 columns]
