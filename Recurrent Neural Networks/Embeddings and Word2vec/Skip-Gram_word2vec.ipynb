# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter

threshold = 1e-5
count = Counter(words)
total_number_words = len(words)
frequencies = {word:appearances/total_number_words for word, appearances in count.items()}
# Comparing the Probability to drop lower than a random pick in the uniform. 
# We are using the accumaltive probability. Doing < than drop, you are covering all probabilities of the unif
# density function below the threshold.
train_words = [integer for integer in int_words if np.random.uniform()<np.sqrt(threshold/frequencies[int_to_vocab[integer]])] 
print('Total words: ',total_number_words)
print('Remaining words: ',len(train_words))
# Out:
# Total words:  16680599
# Remaining words:  4626406

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    r = np.random.random_integers(1,window_size)
    targets = list()
    if idx <= window_size-1:
        targets.extend(words[:idx])
        targets.extend(words[idx+1:idx+r+1])
    else:
        targets.extend(words[idx-r:idx])
        targets.extend(words[idx+1:idx+r+1])
        
    return targets

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=(None), name='inputs')
    labels = tf.placeholder(tf.int32, shape=(None, 1), name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform(shape=(n_vocab, n_embedding), minval=-1, maxval=1, dtype=tf.float32)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, ids=inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1), name='weights_softmax') # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab, 1), name='bias_softmax') # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels=labels, 
                                      inputs=embed, num_sampled=n_sampled, num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random

with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: This function is deprecated. Please call randint(1, 10 + 1) instead
#   after removing the cwd from sys.path.
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6179 0.0840 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5813 0.0816 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4585 0.0829 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5718 0.0818 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4639 0.0818 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4942 0.0815 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5275 0.0817 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.4952 0.0826 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4216 0.0843 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3800 0.0854 sec/batch
# Nearest to or: nottinghamshire, liv, encompasses, orgel, hv, robe, response, kahanamoku,
# Nearest to state: literacy, achilles, haskalah, denslow, friedrich, neighbor, neumann, patay,
# Nearest to first: dreadnought, fra, weald, malinowski, warehouses, discipline, chloe, talkative,
# Nearest to all: tailed, gast, mithra, theodora, articulated, grounding, prototyping, unholy,
# Nearest to some: cin, outlets, msp, undertook, outlasted, cortland, nature, epigr,
# Nearest to and: variability, chamonix, sagas, reality, bissell, cherokee, turkeys, skirmishes,
# Nearest to three: slips, dunbartonshire, european, strictness, experiences, ubi, unambiguously, beryllium,
# Nearest to however: gunpoint, aleksandr, oversea, edm, resources, northernmost, dsa, contracts,
# Nearest to arts: femininity, pomeranian, visionary, amazonas, mabinogion, philosophiques, adhemar, alford,
# Nearest to shown: disgust, fielders, baiting, carvalho, resigning, rejecting, testaments, datagram,
# Nearest to file: coahuila, dorian, rdr, tripped, neumann, sinew, erecting, strontium,
# Nearest to quite: multipurpose, grades, sala, liners, parentage, ogden, castrati, aluma,
# Nearest to award: lindisfarne, hellenic, deliveries, delegated, betrothal, reigned, bjelke, aphrodite,
# Nearest to operations: mainstreaming, morphologically, unfinished, deinstitutionalization, claimant, sesame, denoted, goalposts,
# Nearest to hit: venatici, typographical, compactification, criticised, tim, sped, regularly, ankobra,
# Nearest to notes: philby, mitzvah, metazoa, symbolist, muammar, attempted, insidious, permanent,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4587 0.0875 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3454 0.0870 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.2981 0.0884 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2081 0.0884 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1687 0.0885 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1367 0.0891 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0937 0.0893 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0686 0.0897 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9979 0.0900 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0129 0.0888 sec/batch
# Nearest to or: nottinghamshire, response, encompasses, liv, uk, familiarity, presentation, robe,
# Nearest to state: literacy, lower, abusers, neumann, achilles, friedrich, internal, denslow,
# Nearest to first: discipline, dreadnought, fra, consumption, malinowski, warehouses, maintains, burning,
# Nearest to all: agencies, increases, articulated, may, personal, gast, cases, characteristic,
# Nearest to some: nature, undertook, msp, distinguishing, happen, outlets, hit, leased,
# Nearest to and: reality, variability, chamonix, primitive, foundation, internationally, cherokee, sagas,
# Nearest to three: european, slips, experiences, dunbartonshire, property, strictness, learn, seemed,
# Nearest to however: resources, contracts, gunpoint, northernmost, directly, aleksandr, nationalist, bend,
# Nearest to arts: femininity, pomeranian, mandated, visionary, amazonas, mabinogion, goods, philosophiques,
# Nearest to shown: movement, rejecting, intersect, thwarted, alster, precinct, disgust, legal,
# Nearest to file: dorian, neumann, coahuila, very, susceptibility, sinew, tripped, rdr,
# Nearest to quite: grades, deployment, sala, secondary, school, has, uefa, liners,
# Nearest to award: lindisfarne, delegated, programmers, hellenic, deliveries, aphrodite, congar, kenji,
# Nearest to operations: transmutations, targets, denoted, unfinished, morphologically, war, goalposts, maximum,
# Nearest to hit: venatici, regularly, typographical, criticised, tim, some, sped, constitute,
# Nearest to notes: symbolist, metazoa, attempted, permanent, continuously, muammar, swansea, mitzvah,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9424 0.0912 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8907 0.0907 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8883 0.0910 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8507 0.0907 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8196 0.0904 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8219 0.0907 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8138 0.0908 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7777 0.0912 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7886 0.0911 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7792 0.0909 sec/batch
# Nearest to or: liv, nottinghamshire, response, encompasses, assisted, poul, weavers, supplying,
# Nearest to state: literacy, friedrich, haskalah, neighbor, neumann, achilles, abusers, lower,
# Nearest to first: discipline, dreadnought, fra, malinowski, vote, warehouses, burning, chloe,
# Nearest to all: obligation, agencies, increases, articulated, gast, characteristic, may, personal,
# Nearest to some: nature, distinguishing, michaels, msp, undertook, cin, libertarian, outlets,
# Nearest to and: variability, skirmishes, internationally, sagas, chamonix, reality, bissell, recession,
# Nearest to three: slips, experiences, european, dunbartonshire, seemed, strictness, hazards, raf,
# Nearest to however: resources, contracts, northernmost, gunpoint, aleksandr, bend, ore, anthropology,
# Nearest to arts: pomeranian, visionary, femininity, publisher, mabinogion, theocracy, mandated, amazonas,
# Nearest to shown: rejecting, intersect, disgust, movement, alster, thwarted, grouping, consume,
# Nearest to file: susceptibility, neumann, very, dorian, depart, sf, coahuila, erecting,
# Nearest to quite: grades, deployment, secondary, liners, sala, uefa, has, school,
# Nearest to award: hellenic, delegated, lindisfarne, rough, programmers, reigned, deliveries, kennedy,
# Nearest to operations: unfinished, targets, claimant, denoted, morphologically, noon, transmutations, goalposts,
# Nearest to hit: venatici, typographical, tim, criticised, regularly, constitute, sped, organism,
# Nearest to notes: continuously, muammar, metazoa, biology, comprises, philby, mitzvah, burma,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7566 0.0921 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7707 0.0915 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7383 0.0922 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7140 0.0950 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7636 0.0924 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6915 0.0919 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6965 0.0912 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7312 0.0918 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6951 0.0922 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6668 0.0929 sec/batch
# Nearest to or: nottinghamshire, liv, response, poul, weavers, supplying, encompasses, quipped,
# Nearest to state: literacy, haskalah, friedrich, denslow, achilles, computability, nurse, states,
# Nearest to first: discipline, dreadnought, fra, warehouses, squarely, middle, malinowski, vote,
# Nearest to all: obligation, gast, grounding, agencies, increases, jocelyn, cases, may,
# Nearest to some: nature, cortland, cin, msp, michaels, croissants, dualistic, distinguishing,
# Nearest to and: chamonix, skirmishes, sagas, variability, internationally, conjugations, bissell, contradicts,
# Nearest to three: slips, four, one, hazards, dunbartonshire, raf, est, versailles,
# Nearest to however: resources, gunpoint, contracts, aleksandr, northernmost, bend, anthropology, ore,
# Nearest to arts: pomeranian, mabinogion, theocracy, visionary, femininity, amazonas, publisher, adhemar,
# Nearest to shown: datagram, disgust, intersect, nurse, testaments, rejecting, vestry, consume,
# Nearest to file: susceptibility, coahuila, neumann, erecting, tripped, very, dorian, depart,
# Nearest to quite: grades, liners, secondary, deployment, multipurpose, aluma, desktops, sala,
# Nearest to award: lindisfarne, delegated, betrothal, deliveries, rough, kennedy, hellenic, reigned,
# Nearest to operations: unfinished, targets, claimant, deinstitutionalization, noon, morphologically, goalposts, sesame,
# Nearest to hit: venatici, typographical, regularly, criticised, tim, compactification, sped, organism,
# Nearest to notes: philby, continuously, muammar, mitzvah, jammu, metazoa, burma, biology,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6812 0.0935 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6690 0.0943 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6164 0.0921 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6380 0.0919 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6408 0.0918 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6339 0.0914 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6152 0.0684 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5774 0.0919 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5264 0.0916 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5072 0.0910 sec/batch
# Nearest to or: nottinghamshire, liv, response, poul, supplying, certain, weavers, hysteria,
# Nearest to state: literacy, haskalah, denslow, states, achilles, friedrich, nurse, investors,
# Nearest to first: dreadnought, fra, discipline, warehouses, squarely, mugshot, talkative, waffle,
# Nearest to all: obligation, gast, grounding, mithra, verifying, agencies, tailed, adversaries,
# Nearest to some: nature, croissants, msp, cortland, workplace, ale, predetermined, cin,
# Nearest to and: chamonix, sagas, skirmishes, variability, internationally, conjugations, bissell, contradicts,
# Nearest to three: four, one, slips, est, jan, tennis, raf, dunbartonshire,
# Nearest to however: gunpoint, resources, contracts, bend, northernmost, anthropology, salinity, aleksandr,
# Nearest to arts: amazonas, pomeranian, mabinogion, theocracy, femininity, exposition, adhemar, preposition,
# Nearest to shown: datagram, intersect, disgust, nurse, vestry, testaments, thwarted, baiting,
# Nearest to file: susceptibility, coahuila, neumann, erecting, very, tripped, sauropod, asoka,
# Nearest to quite: grades, secondary, aluma, than, ucblogo, gaynor, has, liners,
# Nearest to award: betrothal, presentational, lindisfarne, kennedy, deliveries, rough, catalina, dilemma,
# Nearest to operations: unfinished, targets, deinstitutionalization, morphologically, goalposts, denoted, noon, carriages,
# Nearest to hit: venatici, typographical, regularly, criticised, compactification, tim, penetrated, ankobra,
# Nearest to notes: philby, lesson, continuously, muammar, jammu, mitzvah, metazoa, insidious,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4918 0.0925 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4931 0.0943 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4651 0.0922 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5200 0.0915 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4852 0.0921 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4714 0.0923 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4780 0.0924 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3892 0.0929 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4310 0.0933 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.3987 0.0937 sec/batch
# Nearest to or: nottinghamshire, response, liv, hysteria, poul, certain, supplying, altruistic,
# Nearest to state: literacy, haskalah, denslow, states, achilles, investors, friedrich, nurse,
# Nearest to first: dreadnought, fra, warehouses, discipline, squarely, mugshot, talkative, waffle,
# Nearest to all: obligation, gast, grounding, say, verifying, metric, mithra, jocelyn,
# Nearest to some: croissants, nature, distinguishing, ale, nasal, workplace, cortland, msp,
# Nearest to and: sagas, variability, chamonix, internationally, skirmishes, conjugations, primitive, turkeys,
# Nearest to three: four, slips, one, est, hazards, dunbartonshire, raf, theresia,
# Nearest to however: contracts, gunpoint, resources, nonverbal, greed, utilise, bend, northernmost,
# Nearest to arts: amazonas, pomeranian, exposition, mabinogion, theocracy, publisher, adhemar, monosaccharides,
# Nearest to shown: datagram, intersect, disgust, testaments, nurse, vestry, baiting, consume,
# Nearest to file: susceptibility, coahuila, neumann, erecting, chuang, use, tripped, algorithm,
# Nearest to quite: grades, secondary, deployment, aluma, has, ivanov, than, multipurpose,
# Nearest to award: presentational, kennedy, betrothal, lindisfarne, trichomes, deliveries, catalina, bioavailability,
# Nearest to operations: unfinished, targets, goalposts, deinstitutionalization, morphologically, claimant, apache, denoted,
# Nearest to hit: venatici, typographical, criticised, regularly, tim, penetrated, ankobra, attempt,
# Nearest to notes: lesson, continuously, philby, muammar, jammu, insidious, metazoa, symbolist,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4283 0.0938 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4073 0.0926 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4212 0.0924 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3974 0.0927 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4247 0.0946 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4518 0.0919 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3795 0.0923 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3946 0.0923 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4105 0.0920 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3793 0.0920 sec/batch
# Nearest to or: liv, nottinghamshire, poul, hysteria, supplying, altruistic, certain, response,
# Nearest to state: literacy, haskalah, states, denslow, investors, establishes, achilles, argo,
# Nearest to first: dreadnought, fra, discipline, warehouses, talkative, squarely, waffle, ibm,
# Nearest to all: obligation, gast, grounding, mithra, cases, say, jocelyn, increases,
# Nearest to some: distinguishing, croissants, nasal, nature, cortland, cvbg, ale, libertarian,
# Nearest to and: chamonix, sagas, conjugations, internationally, demystified, skirmishes, retief, ces,
# Nearest to three: four, one, slips, est, raf, five, dunbartonshire, six,
# Nearest to however: contracts, gunpoint, resources, oversea, bend, reorganizing, proportion, northernmost,
# Nearest to arts: amazonas, pomeranian, exposition, mabinogion, publisher, seminar, theocracy, adhemar,
# Nearest to shown: intersect, datagram, disgust, synonymously, nurse, down, rider, consume,
# Nearest to file: susceptibility, coahuila, use, neumann, erecting, chuang, tripped, asoka,
# Nearest to quite: grades, secondary, deployment, has, ucblogo, aluma, multipurpose, guaranteed,
# Nearest to award: kennedy, presentational, betrothal, trichomes, lindisfarne, catalina, deliveries, leitch,
# Nearest to operations: targets, goalposts, unfinished, apache, deinstitutionalization, carriages, morphologically, denoted,
# Nearest to hit: venatici, typographical, tim, criticised, regularly, offeree, emigrate, showers,
# Nearest to notes: lesson, continuously, philby, muammar, jammu, insidious, metazoa, mitzvah,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3708 0.0929 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3756 0.0923 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3658 0.0920 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3618 0.0915 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3963 0.0917 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3605 0.0916 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3640 0.0943 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3692 0.0926 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3126 0.0926 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3204 0.0929 sec/batch
# Nearest to or: liv, poul, nottinghamshire, supplying, hysteria, altruistic, response, consecutively,
# Nearest to state: literacy, states, haskalah, denslow, establishes, investors, achilles, legislature,
# Nearest to first: dreadnought, discipline, fra, warehouses, talkative, ibm, turbojets, voivodship,
# Nearest to all: obligation, gast, mithra, grounding, say, cases, jocelyn, verifying,
# Nearest to some: distinguishing, croissants, nasal, cortland, nature, libertarian, loaf, cvbg,
# Nearest to and: internationally, sagas, chamonix, demystified, skirmishes, conjugations, securing, ces,
# Nearest to three: four, one, five, six, est, zero, slips, ubi,
# Nearest to however: contracts, resources, gunpoint, reorganizing, nationalist, greed, edm, oversea,
# Nearest to arts: amazonas, exposition, pomeranian, seminar, mabinogion, publisher, theocracy, adhemar,
# Nearest to shown: intersect, datagram, nurse, synonymously, disgust, down, rider, consume,
# Nearest to file: susceptibility, use, coahuila, chuang, neumann, tripped, demigods, xml,
# Nearest to quite: grades, secondary, has, desktops, ucblogo, than, aluma, multipurpose,
# Nearest to award: kennedy, presentational, betrothal, trichomes, catalina, lindisfarne, score, leitch,
# Nearest to operations: unfinished, targets, goalposts, deinstitutionalization, apache, carriages, denoted, noon,
# Nearest to hit: venatici, tim, offeree, typographical, regularly, showers, criticised, cumulant,
# Nearest to notes: lesson, continuously, muammar, philby, jammu, potok, burma, kearney,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3031 0.0944 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2795 0.0924 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3876 0.0922 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3673 0.0919 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3651 0.0922 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2828 0.0922 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3158 0.0918 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3184 0.0917 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2270 0.0921 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3077 0.0923 sec/batch
# Nearest to or: liv, hysteria, poul, nottinghamshire, encompasses, borrower, altruistic, supplying,
# Nearest to state: literacy, states, haskalah, denslow, establishes, investors, alp, legislature,
# Nearest to first: dreadnought, fra, waffle, voivodship, talkative, discipline, warehouses, affiliation,
# Nearest to all: obligation, gast, mithra, say, grounding, riemannian, verifying, findable,
# Nearest to some: distinguishing, croissants, nature, nasal, libertarian, cortland, dualistic, cvbg,
# Nearest to and: internationally, skirmishes, chamonix, sagas, demystified, conjugations, securing, ethica,
# Nearest to three: four, one, six, five, est, zero, ubi, seven,
# Nearest to however: contracts, nationalist, gunpoint, greed, reorganizing, nonverbal, did, controversial,
# Nearest to arts: exposition, seminar, amazonas, pomeranian, skeptics, loyola, publisher, theocracy,
# Nearest to shown: intersect, datagram, nurse, disgust, synonymously, rider, carvalho, down,
# Nearest to file: susceptibility, use, coahuila, xml, chuang, neumann, tripped, demigods,
# Nearest to quite: grades, ladder, has, secondary, ucblogo, aluma, bundestag, multipurpose,
# Nearest to award: kennedy, presentational, score, trichomes, catalina, bjelke, rsha, bioavailability,
# Nearest to operations: targets, unfinished, goalposts, lumpur, deinstitutionalization, carriages, apache, airborne,
# Nearest to hit: venatici, tim, offeree, regularly, showers, saragossa, soundtrack, odoacer,
# Nearest to notes: lesson, philby, potok, continuously, jammu, cosmonauts, muammar, burma,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2848 0.0930 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2803 0.0921 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3230 0.0445 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2463 0.0922 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2109 0.0914 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2108 0.0911 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1978 0.0912 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1680 0.0922 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2196 0.0917 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1811 0.0916 sec/batch
# Nearest to or: liv, hysteria, poul, nottinghamshire, altruistic, supplying, borrower, couples,
# Nearest to state: literacy, haskalah, states, establishes, denslow, legislature, vermont, investors,
# Nearest to first: dreadnought, voivodship, fra, talkative, waffle, chalmers, polling, warehouses,
# Nearest to all: obligation, gast, mithra, grounding, verifying, say, riemannian, certifies,
# Nearest to some: distinguishing, croissants, nasal, cvbg, epigr, defer, libertarian, qualities,
# Nearest to and: internationally, chamonix, variability, sagas, demystified, skirmishes, complexes, philippines,
# Nearest to three: four, one, five, six, zero, est, ubi, two,
# Nearest to however: greed, nationalist, fail, nonverbal, gunpoint, contracts, reorganizing, did,
# Nearest to arts: exposition, amazonas, seminar, skeptics, pomeranian, publisher, stagnated, drama,
# Nearest to shown: datagram, intersect, nurse, disgust, graphing, synonymously, down, rider,
# Nearest to file: susceptibility, coahuila, xml, use, chuang, images, tripped, neumann,
# Nearest to quite: grades, ladder, ucblogo, bundestag, aluma, than, has, guaranteed,
# Nearest to award: kennedy, score, presentational, bjelke, trichomes, nominations, catalina, bioavailability,
# Nearest to operations: targets, denoted, airborne, lumpur, apache, represents, unfinished, goalposts,
# Nearest to hit: venatici, offeree, tim, showers, soundtrack, fielding, tougher, cumulant,
# Nearest to notes: lesson, potok, continuously, philby, jammu, cosmonauts, kearney, mentioning,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2441 0.0929 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2248 0.0923 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1809 0.0924 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1037 0.0930 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1774 0.0932 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1162 0.0934 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1496 0.0931 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1495 0.0926 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2012 0.0923 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1643 0.0926 sec/batch
# Nearest to or: hysteria, altruistic, liv, couples, consecutively, nottinghamshire, enumeration, poul,
# Nearest to state: states, literacy, haskalah, establishes, denslow, legislature, vermont, counties,
# Nearest to first: dreadnought, voivodship, discipline, fra, chalmers, hem, talkative, turbojets,
# Nearest to all: obligation, mithra, say, grounding, findable, riemannian, gast, verifying,
# Nearest to some: distinguishing, croissants, nasal, cvbg, defer, qualities, epigr, libertarian,
# Nearest to and: internationally, demystified, conjugations, chamonix, complexes, sagas, variability, enthusiasms,
# Nearest to three: four, one, five, six, zero, ubi, est, two,
# Nearest to however: fail, nonverbal, nationalist, contracts, gunpoint, edm, did, greed,
# Nearest to arts: exposition, amazonas, seminar, skeptics, pomeranian, loyola, schools, graduates,
# Nearest to shown: intersect, datagram, nurse, disgust, baiting, synonymously, primal, binge,
# Nearest to file: susceptibility, coahuila, use, xml, tripped, erecting, neumann, chuang,
# Nearest to quite: grades, ladder, bundestag, has, ucblogo, than, aluma, multipurpose,
# Nearest to award: kennedy, score, presentational, emmitt, bjelke, catalina, nominations, trichomes,
# Nearest to operations: targets, goalposts, unfinished, lumpur, airborne, apache, denoted, represents,
# Nearest to hit: venatici, tim, offeree, soundtrack, showers, fielding, tougher, tournaments,
# Nearest to notes: lesson, mentioning, potok, kearney, jammu, cosmonauts, texts, continuously,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1477 0.0930 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1930 0.0919 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1607 0.0919 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1249 0.0918 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1516 0.0920 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1833 0.0918 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2088 0.0917 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1150 0.0914 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1305 0.0914 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1536 0.0918 sec/batch
# Nearest to or: liv, hysteria, couples, poul, consecutively, altruistic, gynecologists, enumeration,
# Nearest to state: states, literacy, establishes, haskalah, denslow, computability, legislature, vermont,
# Nearest to first: dreadnought, discipline, voivodship, hem, polling, talkative, minimised, ibm,
# Nearest to all: obligation, mithra, gast, say, findable, unholy, grounding, verifying,
# Nearest to some: distinguishing, croissants, nasal, cvbg, epigr, defer, qualities, nature,
# Nearest to and: demystified, internationally, methodist, chamonix, interpolation, conjugations, securing, enthusiasms,
# Nearest to three: four, one, five, six, zero, est, two, seven,
# Nearest to however: nationalist, fail, edm, northernmost, salinity, gunpoint, greed, nonverbal,
# Nearest to arts: exposition, seminar, amazonas, art, skeptics, drama, loyola, graduates,
# Nearest to shown: intersect, datagram, nurse, primal, disgust, graphing, synonymously, psychotic,
# Nearest to file: susceptibility, use, coahuila, xml, erecting, tripped, downloads, neumann,
# Nearest to quite: grades, ladder, than, has, hortatory, ucblogo, bundestag, xn,
# Nearest to award: kennedy, presentational, bjelke, catalina, emmitt, score, bioavailability, nominations,
# Nearest to operations: targets, unfinished, airborne, operation, lumpur, apache, goalposts, carriages,
# Nearest to hit: venatici, offeree, soundtrack, tim, mediocre, fielding, showers, sped,
# Nearest to notes: lesson, potok, cosmonauts, mentioning, kearney, texts, jammu, burma,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1496 0.0927 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1760 0.0920 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1398 0.0915 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1794 0.0922 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1145 0.0929 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1224 0.0922 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1466 0.0927 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1235 0.0927 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2056 0.0920 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2078 0.0921 sec/batch
# Nearest to or: hysteria, liv, couples, poul, altruistic, consecutively, engage, gynecologists,
# Nearest to state: states, establishes, haskalah, denslow, literacy, vermont, computability, counties,
# Nearest to first: dreadnought, discipline, polling, voivodship, six, affiliation, chalmers, talkative,
# Nearest to all: obligation, mithra, say, findable, gast, unholy, grounding, riemannian,
# Nearest to some: croissants, distinguishing, nasal, epigr, defer, cvbg, qualities, collective,
# Nearest to and: demystified, internationally, methodist, securing, chamonix, philippines, mellish, enthusiasms,
# Nearest to three: four, one, five, six, zero, two, seven, est,
# Nearest to however: nationalist, fail, edm, nonverbal, did, greed, imposing, immediate,
# Nearest to arts: exposition, seminar, skeptics, amazonas, art, loyola, drama, pomeranian,
# Nearest to shown: intersect, nurse, datagram, disgust, primal, synonymously, psychotic, graphing,
# Nearest to file: susceptibility, coahuila, use, xml, erecting, tripped, downloads, netbsd,
# Nearest to quite: grades, ladder, bundestag, incorporeal, than, hortatory, ucblogo, has,
# Nearest to award: kennedy, catalina, presentational, emmitt, nominations, emmy, bjelke, bioavailability,
# Nearest to operations: operation, targets, unfinished, airborne, lumpur, goalposts, carriages, denoted,
# Nearest to hit: venatici, offeree, tim, soundtrack, shortstop, mediocre, sped, showers,
# Nearest to notes: lesson, potok, mentioning, cosmonauts, texts, codings, kearney, jammu,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2009 0.0934 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.0914 0.0924 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1115 0.0918 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.0837 0.0915 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 3.9991 0.0922 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1295 0.0926 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1296 0.0918 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.0843 0.0923 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1492 0.0206 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0756 0.0921 sec/batch
# Nearest to or: liv, hysteria, couples, poul, altruistic, consecutively, supplying, borrower,
# Nearest to state: states, establishes, counties, literacy, haskalah, vermont, shenandoah, denslow,
# Nearest to first: dreadnought, six, polling, voivodship, hem, discipline, ibm, turbojets,
# Nearest to all: obligation, findable, say, mithra, grounding, broadcasters, gast, riemannian,
# Nearest to some: croissants, distinguishing, nasal, epigr, cvbg, defer, collective, qualities,
# Nearest to and: internationally, demystified, chamonix, securing, ravi, intense, sd, canadians,
# Nearest to three: four, one, five, zero, six, two, seven, est,
# Nearest to however: nonverbal, nationalist, did, fail, possible, salinity, edm, specific,
# Nearest to arts: art, exposition, seminar, skeptics, schools, drama, amazonas, exhibited,
# Nearest to shown: intersect, datagram, nurse, disgust, rider, graphing, synonymously, primal,
# Nearest to file: susceptibility, xml, use, coahuila, downloads, netbsd, erecting, enciclopedia,
# Nearest to quite: grades, ladder, than, entail, hortatory, ucblogo, incorporeal, has,
# Nearest to award: kennedy, catalina, nominations, emmy, academy, emmitt, nominated, presentational,
# Nearest to operations: airborne, targets, operation, lumpur, unfinished, denoted, deinstitutionalization, goalposts,
# Nearest to hit: venatici, offeree, tim, sped, shortstop, nicks, mediocre, trunks,
# Nearest to notes: lesson, mentioning, potok, cosmonauts, codings, kearney, jammu, texts,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0480 0.0927 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0298 0.0915 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0752 0.0918 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0415 0.0921 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0576 0.0923 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0082 0.0913 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0683 0.0918 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0564 0.0918 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0753 0.0923 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0030 0.0927 sec/batch
# Nearest to or: liv, couples, poul, hysteria, consecutively, altruistic, pacing, have,
# Nearest to state: states, establishes, haskalah, literacy, computability, counties, vermont, denslow,
# Nearest to first: dreadnought, hem, chalmers, six, minimised, voivodship, fra, zel,
# Nearest to all: obligation, riemannian, findable, grounding, inadequately, broadcasters, unholy, mithra,
# Nearest to some: croissants, distinguishing, nasal, cvbg, epigr, defer, collective, qualities,
# Nearest to and: internationally, demystified, ravi, securing, intense, chamonix, variability, is,
# Nearest to three: four, one, five, zero, six, two, seven, est,
# Nearest to however: fail, nationalist, did, nonverbal, salinity, imposing, rightly, biloxi,
# Nearest to arts: exposition, art, seminar, amazonas, drama, skeptics, schools, affiliated,
# Nearest to shown: datagram, nurse, intersect, disgust, euglenids, binge, swallowed, primal,
# Nearest to file: susceptibility, coahuila, xml, use, netbsd, downloads, tripped, erecting,
# Nearest to quite: grades, ladder, hortatory, bundestag, ucblogo, than, entail, tenants,
# Nearest to award: kennedy, catalina, emmy, nominations, nominated, presentational, bioavailability, emmitt,
# Nearest to operations: operation, targets, airborne, denoted, lumpur, represents, unfinished, deinstitutionalization,
# Nearest to hit: venatici, offeree, fielding, shortstop, tim, mediocre, sped, nicks,
# Nearest to notes: lesson, mentioning, texts, cosmonauts, potok, kearney, jammu, tuned,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9672 0.0945 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0151 0.0934 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9638 0.0930 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0271 0.0924 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0202 0.0926 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 3.9909 0.0931 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0050 0.0926 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0640 0.0922 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0245 0.0924 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0190 0.0923 sec/batch
# Nearest to or: couples, liv, hysteria, altruistic, have, poul, consecutively, gynecologists,
# Nearest to state: states, establishes, computability, vermont, counties, literacy, haskalah, inquire,
# Nearest to first: dreadnought, minimised, hem, discipline, transporter, polling, six, zel,
# Nearest to all: obligation, riemannian, findable, say, inadequately, broadcasters, mithra, tentacles,
# Nearest to some: croissants, distinguishing, cvbg, nasal, epigr, collective, qualities, amusingly,
# Nearest to and: demystified, is, of, internationally, complexes, canadians, motivating, bonewits,
# Nearest to three: four, one, five, zero, six, two, seven, nine,
# Nearest to however: fail, salinity, nonverbal, did, nationalist, edm, possible, proportion,
# Nearest to arts: art, seminar, exposition, amazonas, skeptics, drama, schools, affiliated,
# Nearest to shown: intersect, disgust, euglenids, nurse, datagram, primal, kh, psychotic,
# Nearest to file: susceptibility, coahuila, use, xml, tripped, downloads, selby, netbsd,
# Nearest to quite: grades, ladder, hortatory, bundestag, ucblogo, deceptively, entail, than,
# Nearest to award: nominations, emmy, catalina, kennedy, nominated, bioavailability, emmitt, resemblances,
# Nearest to operations: operation, unfinished, lumpur, targets, apache, deinstitutionalization, goalposts, airborne,
# Nearest to hit: venatici, offeree, mediocre, shortstop, tim, fielding, sped, nicks,
# Nearest to notes: lesson, texts, mentioning, cosmonauts, kearney, potok, jammu, tuned,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0237 0.0939 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0573 0.0923 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0401 0.0920 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.9923 0.0920 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0449 0.0916 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0249 0.0918 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0215 0.0920 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0123 0.0921 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0552 0.0926 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0567 0.0926 sec/batch
# Nearest to or: couples, liv, poul, hysteria, have, consecutively, gynecologists, pacing,
# Nearest to state: states, establishes, vermont, computability, counties, literacy, inquire, haskalah,
# Nearest to first: dreadnought, minimised, hem, polling, six, discipline, voivodship, occurred,
# Nearest to all: obligation, findable, mithra, riemannian, unholy, inadequately, say, tentacles,
# Nearest to some: croissants, cvbg, distinguishing, nasal, epigr, collective, qualities, esarhaddon,
# Nearest to and: of, demystified, ravi, internationally, securing, intense, canadians, methodist,
# Nearest to three: four, one, five, zero, six, two, seven, nine,
# Nearest to however: fail, did, salinity, nationalist, biloxi, nonverbal, northernmost, subjugation,
# Nearest to arts: art, seminar, skeptics, exposition, amazonas, drama, loyola, graduates,
# Nearest to shown: intersect, datagram, disgust, nurse, euglenids, kh, celts, primal,
# Nearest to file: susceptibility, use, coahuila, selby, xml, tripped, erecting, downloads,
# Nearest to quite: grades, ladder, entail, ucblogo, than, hortatory, desktops, bundestag,
# Nearest to award: emmy, nominations, catalina, nominated, best, kennedy, presentational, emmitt,
# Nearest to operations: unfinished, operation, lumpur, targets, deinstitutionalization, apache, goalposts, airborne,
# Nearest to hit: venatici, offeree, nicks, mediocre, shortstop, showers, fielding, sped,
# Nearest to notes: lesson, mentioning, cosmonauts, potok, kearney, texts, jammu, tuned,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0048 0.0940 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9642 0.0928 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.9785 0.0927 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0281 0.0929 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0528 0.0926 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0782 0.0922 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0909 0.0926 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0072 0.0925 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9992 0.0926 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0234 0.0922 sec/batch
# Nearest to or: liv, couples, have, poul, gynecologists, pacing, consecutively, hysteria,
# Nearest to state: states, counties, establishes, vermont, computability, shenandoah, inquire, haskalah,
# Nearest to first: dreadnought, polling, minimised, hem, occurred, voivodship, discipline, half,
# Nearest to all: obligation, findable, mithra, riemannian, broadcasters, say, inadequately, tentacles,
# Nearest to some: croissants, cvbg, nasal, collective, distinguishing, epigr, caruana, libertarian,
# Nearest to and: demystified, internationally, of, is, ravi, intense, conjugations, xxxix,
# Nearest to three: four, five, one, zero, six, two, seven, nine,
# Nearest to however: fail, did, nationalist, salinity, imposing, nonverbal, edm, biloxi,
# Nearest to arts: art, seminar, exposition, skeptics, graduates, affiliated, schools, drama,
# Nearest to shown: intersect, datagram, disgust, euglenids, kh, nurse, celts, primal,
# Nearest to file: coahuila, selby, tripped, susceptibility, use, enciclopedia, xml, erecting,
# Nearest to quite: grades, ladder, entail, ucblogo, xn, hortatory, bundestag, than,
# Nearest to award: emmy, catalina, nominations, nominated, academy, best, kennedy, winners,
# Nearest to operations: operation, unfinished, lumpur, deinstitutionalization, targets, apache, denoted, interrupts,
# Nearest to hit: venatici, offeree, shortstop, nicks, sped, mediocre, showers, fielding,
# Nearest to notes: lesson, tuned, mentioning, cosmonauts, texts, potok, melody, kearney,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9442 0.0933 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9884 0.0929 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0075 0.0925 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0107 0.0920 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0537 0.0918 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0018 0.0886 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9594 0.0920 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9446 0.0914 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9727 0.0910 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9520 0.0916 sec/batch
# Nearest to or: couples, liv, poul, have, gynecologists, altruistic, enumeration, hysteria,
# Nearest to state: states, counties, establishes, vermont, computability, inquire, shenandoah, census,
# Nearest to first: dreadnought, minimised, half, polling, hem, six, voivodship, occurred,
# Nearest to all: obligation, findable, inadequately, broadcasters, say, mithra, grounding, tentacles,
# Nearest to some: croissants, cvbg, collective, epigr, distinguishing, defer, nasal, qualities,
# Nearest to and: demystified, of, intense, ravi, is, bonewits, tint, ancyra,
# Nearest to three: four, one, five, zero, six, two, seven, nine,
# Nearest to however: fail, salinity, nonverbal, did, biloxi, edm, imposing, maldivian,
# Nearest to arts: art, seminar, skeptics, exposition, martial, drama, schools, affiliated,
# Nearest to shown: intersect, kh, datagram, euglenids, disgust, nurse, jess, psychotic,
# Nearest to file: selby, susceptibility, coahuila, tripped, downloads, enciclopedia, erecting, rtos,
# Nearest to quite: grades, ladder, ucblogo, entail, than, bundestag, hortatory, tenants,
# Nearest to award: academy, nominations, emmy, catalina, best, nominated, bioavailability, filmfare,
# Nearest to operations: operation, unfinished, lumpur, deinstitutionalization, denoted, interrupts, targets, fairey,
# Nearest to hit: venatici, offeree, shortstop, nicks, showers, sped, trunks, fielding,
# Nearest to notes: lesson, tuned, mentioning, kearney, melody, potok, cosmonauts, texts,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9571 0.0926 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.8776 0.0917 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9808 0.0918 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9808 0.0924 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9985 0.0924 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9624 0.0927 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8569 0.0929 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9123 0.0931 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8735 0.0926 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9718 0.0927 sec/batch
# Nearest to or: have, couples, liv, poul, consecutively, altruistic, gynecologists, hysteria,
# Nearest to state: states, counties, establishes, inquire, vermont, computability, haskalah, census,
# Nearest to first: dreadnought, minimised, redskins, voivodship, polling, since, hem, half,
# Nearest to all: obligation, findable, inadequately, broadcasters, riemannian, mature, tentacles, say,
# Nearest to some: croissants, distinguishing, cvbg, collective, nasal, defer, epigr, libertarian,
# Nearest to and: is, of, demystified, intense, the, in, variability, astatine,
# Nearest to three: four, one, five, zero, two, six, seven, nine,
# Nearest to however: fail, did, salinity, edm, maldivian, imposing, historically, possible,
# Nearest to arts: art, seminar, skeptics, exposition, drama, martial, graduates, affiliated,
# Nearest to shown: disgust, euglenids, intersect, kh, datagram, carvalho, jess, celts,
# Nearest to file: susceptibility, downloads, selby, coahuila, rtos, enciclopedia, erecting, xml,
# Nearest to quite: grades, ladder, entail, tenants, ucblogo, hortatory, than, graceful,
# Nearest to award: emmy, academy, nominated, nominations, catalina, best, winners, bioavailability,
# Nearest to operations: operation, unfinished, lumpur, disregard, deinstitutionalization, fairey, targets, denoted,
# Nearest to hit: venatici, offeree, shortstop, fielding, mediocre, showers, nicks, tim,
# Nearest to notes: lesson, tuned, melody, mentioning, diatonic, kearney, cosmonauts, bps,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9583 0.0933 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9524 0.0924 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9278 0.0930 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9596 0.0920 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.9781 0.0917 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9237 0.0921 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9743 0.0922 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9336 0.0920 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9642 0.0921 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9594 0.0920 sec/batch
# Nearest to or: have, poul, couples, liv, pacing, consecutively, gynecologists, denoted,
# Nearest to state: states, computability, establishes, inquire, vermont, counties, ionosphere, haskalah,
# Nearest to first: minimised, dreadnought, hem, polling, half, since, in, voivodship,
# Nearest to all: broadcasters, obligation, findable, mithra, riemannian, tentacles, mature, say,
# Nearest to some: cvbg, croissants, distinguishing, collective, amusingly, libertarian, caruana, millennialism,
# Nearest to and: is, demystified, of, the, a, motivating, yitzhak, stanhope,
# Nearest to three: four, one, five, zero, two, six, seven, nine,
# Nearest to however: fail, did, salinity, historically, edm, imposing, maldivian, possible,
# Nearest to arts: art, seminar, skeptics, drama, martial, exposition, affiliated, graduates,
# Nearest to shown: kh, intersect, euglenids, psychotic, disgust, datagram, primal, jess,
# Nearest to file: downloads, susceptibility, selby, coahuila, append, tripped, erecting, sharing,
# Nearest to quite: grades, ladder, entail, desktops, ucblogo, deceptively, xn, tenants,
# Nearest to award: academy, best, nominated, emmy, nominations, awards, catalina, winners,
# Nearest to operations: operation, unfinished, deinstitutionalization, lumpur, fairey, disregard, denoted, targets,
# Nearest to hit: venatici, offeree, shortstop, nicks, fielding, showers, tim, trunks,
# Nearest to notes: lesson, tuned, mentioning, melody, estonian, kearney, burma, cosmonauts,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9656 0.0930 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9244 0.0914 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9139 0.0915 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9490 0.0922 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9946 0.0917 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9357 0.0919 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9135 0.0925 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9130 0.0928 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9032 0.0928 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9859 0.0930 sec/batch
# Nearest to or: have, couples, liv, poul, pacing, consecutively, supplying, denoted,
# Nearest to state: states, establishes, inquire, computability, vermont, counties, shenandoah, haskalah,
# ...
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7830 0.0934 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.7926 0.0929 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.7882 0.0927 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.7528 0.0926 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8429 0.0922 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8550 0.0925 sec/batch
# Nearest to or: are, a, as, have, usually, is, only, include,
# Nearest to state: states, counties, census, shenandoah, computability, vermont, achilles, farmington,
# Nearest to first: in, after, since, second, had, was, the, eight,
# Nearest to all: and, are, inadequately, least, since, only, be, same,
# Nearest to some: such, these, have, also, which, from, well, to,
# Nearest to and: of, the, is, a, in, as, with, are,
# Nearest to three: four, two, one, five, zero, seven, six, eight,
# Nearest to however: did, historically, because, fail, the, possible, not, to,
# Nearest to arts: art, martial, soo, drama, reestablishment, shaolin, replaceable, brahmin,
# Nearest to shown: psychotic, that, viewers, lieber, cretians, euglenids, celts, cbc,
# Nearest to file: files, selby, append, enciclopedia, algorithm, downloads, disadvantage, erecting,
# Nearest to quite: entail, tenants, xn, arnaud, grades, ccgs, ucblogo, klinefelter,
# Nearest to award: best, awards, academy, nominated, awarded, oscars, hugos, catalina,
# Nearest to operations: operation, reconstruction, fairey, deinstitutionalization, denoted, lumpur, unfinished, staff,
# Nearest to hit: hits, venatici, varma, sped, nicks, shortstop, showers, cali,
# Nearest to notes: tuned, melody, lesson, scotton, cookbooks, legato, mentioning, trumpet,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7686 0.0934 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8132 0.0920 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8106 0.0919 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8224 0.0922 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.7993 0.0924 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8133 0.0918 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8057 0.0920 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.7993 0.0916 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.7948 0.0916 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8416 0.0917 sec/batch
# Nearest to or: a, as, are, usually, have, is, only, poul,
# Nearest to state: states, vested, counties, computability, census, achilles, establishes, legislature,
# Nearest to first: in, after, since, was, second, had, of, minimised,
# Nearest to all: only, and, least, inadequately, since, are, holds, a,
# Nearest to some: these, such, have, also, to, well, and, other,
# Nearest to and: of, the, is, a, in, with, as, to,
# Nearest to three: four, two, one, five, seven, zero, six, eight,
# Nearest to however: did, because, possible, fail, historically, not, though, occasion,
# Nearest to arts: art, martial, soo, drama, reestablishment, shaolin, replaceable, budo,
# Nearest to shown: that, viewers, psychotic, lieber, shows, cretians, celts, thyroxine,
# Nearest to file: files, selby, append, downloads, enciclopedia, codecs, format, erecting,
# Nearest to quite: entail, xn, arnaud, tenants, ucblogo, ccgs, graceful, grades,
# Nearest to award: awards, best, nominated, academy, awarded, hugos, oscars, nominations,
# Nearest to operations: operation, denoted, fairey, reconstruction, lumpur, deinstitutionalization, unfinished, disregard,
# Nearest to hit: hits, venatici, nicks, varma, sped, shortstop, mosses, ankobra,
# Nearest to notes: tuned, melody, cookbooks, mentioning, lesson, scotton, legato, estonian,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8099 0.0928 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.7790 0.0925 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.7966 0.0931 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.7652 0.0928 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8789 0.0929 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8249 0.0922 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9221 0.0917 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8404 0.0921 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8518 0.0923 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7826 0.0922 sec/batch
# Nearest to or: are, as, a, have, usually, is, means, only,
# Nearest to state: states, counties, vested, achilles, census, shenandoah, computability, legislature,
# Nearest to first: in, after, was, second, since, had, of, at,
# Nearest to all: inadequately, only, since, least, and, are, peerages, same,
# Nearest to some: these, such, have, also, to, and, other, most,
# Nearest to and: of, the, in, a, with, is, as, to,
# Nearest to three: four, two, five, one, zero, seven, six, eight,
# Nearest to however: did, possible, because, not, historically, fail, biloxi, the,
# Nearest to arts: martial, art, soo, drama, reestablishment, budo, shaolin, sparring,
# Nearest to shown: psychotic, viewers, lieber, that, cbc, cretians, thyroxine, bogart,
# Nearest to file: files, selby, append, enciclopedia, downloads, algorithm, sharing, tripped,
# Nearest to quite: entail, arnaud, xn, tenants, ccgs, individualistic, jacobus, graceful,
# Nearest to award: awards, best, academy, nominated, awarded, hugos, oscars, nomination,
# Nearest to operations: operation, denoted, reconstruction, fairey, unfinished, lumpur, disregard, deinstitutionalization,
# Nearest to hit: hits, venatici, nicks, varma, ankobra, madre, mixes, showers,
# Nearest to notes: tuned, melody, mentioning, scotton, cookbooks, legato, note, lesson,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7460 0.0930 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8124 0.0917 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7496 0.0925 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8152 0.0923 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.7831 0.0916 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8047 0.0917 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.7983 0.0612 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.7885 0.0927 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7637 0.0915 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8129 0.0913 sec/batch
# Nearest to or: as, are, a, have, usually, of, is, include,
# Nearest to state: states, census, counties, shenandoah, achilles, vested, capitol, computability,
# Nearest to first: in, after, was, of, second, since, the, had,
# Nearest to all: and, only, inadequately, since, a, least, are, holds,
# Nearest to some: these, such, have, other, also, well, as, most,
# Nearest to and: of, the, in, a, is, from, with, by,
# Nearest to three: four, two, one, five, seven, zero, six, eight,
# Nearest to however: did, possible, because, not, though, historically, fail, first,
# Nearest to arts: art, martial, soo, drama, reestablishment, shaolin, budo, kalarippayattu,
# Nearest to shown: psychotic, viewers, cbc, lieber, that, shows, kh, thyroxine,
# Nearest to file: files, selby, append, format, executable, enciclopedia, downloads, algorithm,
# Nearest to quite: entail, tenants, arnaud, ccgs, xn, desktops, multipurpose, bethel,
# Nearest to award: best, awards, academy, nominated, hugos, oscars, awarded, nomination,
# Nearest to operations: operation, denoted, reconstruction, fairey, unfinished, lumpur, deinstitutionalization, disregard,
# Nearest to hit: venatici, hits, varma, nicks, trunks, showers, ankobra, mosses,
# Nearest to notes: tuned, note, scotton, lesson, melody, mentioning, cookbooks, legato,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7660 0.0924 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7664 0.0916 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7847 0.0920 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8158 0.0927 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.7701 0.0919 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.7597 0.0918 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8272 0.0924 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.6733 0.0929 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7711 0.0933 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7146 0.0935 sec/batch
# Nearest to or: are, as, a, have, usually, of, is, in,
# Nearest to state: states, counties, census, vested, shenandoah, achilles, computability, institution,
# Nearest to first: in, after, since, the, of, was, second, eight,
# Nearest to all: and, are, only, a, inadequately, be, since, least,
# Nearest to some: these, have, other, such, to, as, and, which,
# Nearest to and: of, the, in, is, a, with, as, to,
# Nearest to three: four, two, one, five, zero, seven, six, eight,
# Nearest to however: did, because, the, not, was, first, to, historically,
# Nearest to arts: art, martial, soo, drama, reestablishment, shaolin, organized, budo,
# Nearest to shown: psychotic, viewers, that, lieber, shows, cbc, cretians, cezanne,
# Nearest to file: files, selby, append, enciclopedia, executable, downloads, algorithm, format,
# Nearest to quite: entail, tenants, arnaud, xn, ccgs, recurring, klinefelter, jacobus,
# Nearest to award: best, academy, awards, nominated, awarded, oscars, hugos, nomination,
# Nearest to operations: operation, reconstruction, fairey, denoted, unfinished, lumpur, deinstitutionalization, specificity,
# Nearest to hit: hits, venatici, varma, nicks, watermelon, mosses, ankobra, showers,
# Nearest to notes: tuned, melody, lesson, scotton, cookbooks, note, mentioning, legato,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7317 0.0943 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7579 0.0926 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8122 0.0929 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7397 0.0932 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7577 0.0923 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8572 0.0924 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7684 0.0922 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7597 0.0924 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7882 0.0923 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8008 0.0925 sec/batch
# Nearest to or: are, as, usually, a, have, is, of, and,
# Nearest to state: census, counties, states, computability, shenandoah, institution, vested, feedback,
# Nearest to first: in, after, of, second, was, the, since, eight,
# Nearest to all: and, are, least, inadequately, only, a, be, the,
# Nearest to some: these, such, have, also, other, as, most, well,
# Nearest to and: of, the, a, is, in, as, with, from,
# Nearest to three: four, two, one, five, zero, seven, six, eight,
# Nearest to however: did, because, not, the, possible, historically, was, first,
# Nearest to arts: art, martial, soo, drama, organized, reestablishment, replaceable, kalarippayattu,
# Nearest to shown: psychotic, that, viewers, shows, cbc, lieber, cezanne, cretians,
# Nearest to file: files, selby, append, executable, sharing, enciclopedia, downloads, algorithm,
# Nearest to quite: entail, tenants, multipurpose, arnaud, ccgs, xn, recurring, desktops,
# Nearest to award: awards, academy, best, nominated, awarded, hugos, oscars, nomination,
# Nearest to operations: operation, reconstruction, fairey, denoted, unfinished, deinstitutionalization, rcmp, lumpur,
# Nearest to hit: hits, venatici, nicks, watermelon, varma, showers, mosses, mixes,
# Nearest to notes: tuned, melody, cookbooks, scotton, lesson, mentioning, legato, note,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8096 0.0931 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8040 0.0919 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7990 0.0922 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.7743 0.0916 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8012 0.0917 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.7959 0.0918 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.7810 0.0918 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.7880 0.0921 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7937 0.0929 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7640 0.0931 sec/batch
# Nearest to or: as, a, are, usually, have, is, of, in,
# Nearest to state: counties, states, vested, census, achilles, shenandoah, legislature, silhouette,
# Nearest to first: in, after, since, was, second, of, the, eight,
# Nearest to all: and, are, a, only, least, since, the, inadequately,
# Nearest to some: these, such, have, other, also, most, from, as,
# Nearest to and: of, the, a, in, with, from, as, is,
# Nearest to three: four, two, one, five, seven, zero, six, eight,
# Nearest to however: did, because, possible, not, the, historically, most, though,
# Nearest to arts: art, martial, soo, reestablishment, organized, drama, budo, brahmin,
# Nearest to shown: viewers, psychotic, shows, lieber, cbc, that, celts, cezanne,
# Nearest to file: files, append, selby, downloads, executable, sharing, enciclopedia, algorithm,
# Nearest to quite: entail, tenants, arnaud, xn, individualistic, ccgs, multipurpose, ucblogo,
# Nearest to award: awards, best, academy, awarded, hugos, nominated, oscars, presentation,
# Nearest to operations: operation, reconstruction, fairey, denoted, unfinished, deinstitutionalization, lumpur, rcmp,
# Nearest to hit: hits, venatici, varma, watermelon, nicks, mixes, ankobra, showers,
# Nearest to notes: tuned, melody, cookbooks, note, scotton, mentioning, legato, tabulate,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.7914 0.0944 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7910 0.0927 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9032 0.0923 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8169 0.0920 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8371 0.0924 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7395 0.0930 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7100 0.0922 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.7567 0.0921 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7240 0.0925 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8053 0.0923 sec/batch
# Nearest to or: as, a, are, usually, have, is, of, means,
# Nearest to state: counties, states, census, shenandoah, vested, achilles, oklahoma, legislature,
# Nearest to first: in, after, was, since, of, second, eight, at,
# Nearest to all: and, a, that, inadequately, are, since, only, least,
# Nearest to some: these, such, have, other, also, and, most, as,
# Nearest to and: of, the, in, a, with, is, as, from,
# Nearest to three: four, two, one, five, seven, zero, six, nine,
# Nearest to however: did, possible, because, historically, for, not, was, the,
# Nearest to arts: art, martial, soo, budo, organized, among, reestablishment, shaolin,
# Nearest to shown: psychotic, viewers, shows, lieber, that, cbc, celts, cezanne,
# Nearest to file: files, selby, append, downloads, sharing, enciclopedia, format, executable,
# Nearest to quite: entail, tenants, arnaud, xn, klinefelter, individualistic, ccgs, evocative,
# Nearest to award: awards, academy, best, awarded, hugos, nominated, oscars, nomination,
# Nearest to operations: operation, reconstruction, fairey, denoted, lumpur, unfinished, staff, deinstitutionalization,
# Nearest to hit: hits, venatici, nicks, ankobra, madre, varma, showers, watermelon,
# Nearest to notes: tuned, cookbooks, note, melody, mentioning, lesson, scotton, legato,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8142 0.0933 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7643 0.0923 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
